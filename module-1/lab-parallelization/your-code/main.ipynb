# %% [markdown]
# # Parallelization Lab
#
# In this lab, you will be leveraging several concepts you have learned to obtain a list of links from a web page and crawl and index the pages referenced by those links - both sequentially and in parallel. Follow the steps below to complete the lab.

# %% [markdown]
# ## Step 1: Use the requests library to retrieve the content from the URL below.

# %%
import requests

url = 'https://en.wikipedia.org/wiki/Data_science'

# %%
response = requests.get(url).content

# %% [markdown]
# ## Step 2: Use BeautifulSoup to extract a list of all the unique links on the page.

# %%
from bs4 import BeautifulSoup as bs
import re

# %%
soup = bs(response)

list_items = [link['href'] for link in soup.find_all('a', href=True)]
list_items
# soup
# Out:
# ['#mw-head',
#  '#p-search',
#  '/wiki/Information_science',
#  '/wiki/Machine_learning',
#  '/wiki/Data_mining',
#  '/wiki/File:Kernel_Machine.svg',
#  '/wiki/Statistical_classification',
#  '/wiki/Cluster_analysis',
#  '/wiki/Regression_analysis',
#  '/wiki/Anomaly_detection',
#  '/wiki/Automated_machine_learning',
#  '/wiki/Association_rule_learning',
#  '/wiki/Reinforcement_learning',
#  '/wiki/Structured_prediction',
#  '/wiki/Feature_engineering',
#  '/wiki/Feature_learning',
#  '/wiki/Online_machine_learning',
#  '/wiki/Semi-supervised_learning',
#  '/wiki/Unsupervised_learning',
#  '/wiki/Learning_to_rank',
#  '/wiki/Grammar_induction',
#  '/wiki/Supervised_learning',
#  '/wiki/Statistical_classification',
#  '/wiki/Regression_analysis',
#  '/wiki/Decision_tree_learning',
#  '/wiki/Ensemble_learning',
#  '/wiki/Bootstrap_aggregating',
#  '/wiki/Boosting_(machine_learning)',
#  '/wiki/Random_forest',
#  '/wiki/K-nearest_neighbors_algorithm',
#  '/wiki/Linear_regression',
#  '/wiki/Naive_Bayes_classifier',
#  '/wiki/Artificial_neural_network',
#  '/wiki/Logistic_regression',
#  '/wiki/Perceptron',
#  '/wiki/Relevance_vector_machine',
#  '/wiki/Support-vector_machine',
#  '/wiki/Cluster_analysis',
#  '/wiki/BIRCH',
#  '/wiki/CURE_data_clustering_algorithm',
#  '/wiki/Hierarchical_clustering',
#  '/wiki/K-means_clustering',
#  '/wiki/Expectation%E2%80%93maximization_algorithm',
#  '/wiki/DBSCAN',
#  '/wiki/OPTICS_algorithm',
#  '/wiki/Mean-shift',
#  '/wiki/Dimensionality_reduction',
#  '/wiki/Factor_analysis',
#  '/wiki/Canonical_correlation',
#  '/wiki/Independent_component_analysis',
#  '/wiki/Linear_discriminant_analysis',
#  '/wiki/Non-negative_matrix_factorization',
#  '/wiki/Principal_component_analysis',
#  '/wiki/Proper_generalized_decomposition',
#  '/wiki/T-distributed_stochastic_neighbor_embedding',
#  '/wiki/Structured_prediction',
#  '/wiki/Graphical_model',
#  '/wiki/Bayesian_network',
#  '/wiki/Conditional_random_field',
#  '/wiki/Hidden_Markov_model',
#  '/wiki/Anomaly_detection',
#  '/wiki/K-nearest_neighbors_classification',
#  '/wiki/Local_outlier_factor',
#  '/wiki/Artificial_neural_network',
#  '/wiki/Autoencoder',
#  '/wiki/Deep_learning',
#  '/wiki/DeepDream',
#  '/wiki/Multilayer_perceptron',
#  '/wiki/Recurrent_neural_network',
#  '/wiki/Long_short-term_memory',
#  '/wiki/Gated_recurrent_unit',
#  '/wiki/Restricted_Boltzmann_machine',
#  '/wiki/Generative_adversarial_network',
#  '/wiki/Self-organizing_map',
#  '/wiki/Convolutional_neural_network',
#  '/wiki/U-Net',
#  '/wiki/Reinforcement_learning',
#  '/wiki/Q-learning',
#  '/wiki/State%E2%80%93action%E2%80%93reward%E2%80%93state%E2%80%93action',
#  '/wiki/Temporal_difference_learning',
#  '/wiki/Bias%E2%80%93variance_dilemma',
#  '/wiki/Computational_learning_theory',
#  '/wiki/Empirical_risk_minimization',
#  '/wiki/Occam_learning',
#  '/wiki/Probably_approximately_correct_learning',
#  '/wiki/Statistical_learning_theory',
#  '/wiki/Vapnik%E2%80%93Chervonenkis_theory',
#  '/wiki/Conference_on_Neural_Information_Processing_Systems',
#  '/wiki/International_Conference_on_Machine_Learning',
#  '/wiki/Machine_Learning_(journal)',
#  '/wiki/Journal_of_Machine_Learning_Research',
#  'https://arxiv.org/list/cs.LG/recent',
#  '/wiki/Glossary_of_artificial_intelligence',
#  '/wiki/Glossary_of_artificial_intelligence',
#  '/wiki/List_of_datasets_for_machine-learning_research',
#  '/wiki/Outline_of_machine_learning',
#  '/wiki/Template:Machine_learning_bar',
#  '/wiki/Template_talk:Machine_learning_bar',
#  'https://en.wikipedia.org/w/index.php?title=Template:Machine_learning_bar&action=edit',
#  '/wiki/Inter-disciplinary',
#  '/wiki/Knowledge',
#  '/wiki/Unstructured_data',
#  '#cite_note-:0-1',
#  '#cite_note-2',
#  '/wiki/Data_mining',
#  '/wiki/Big_data',
#  '/wiki/Statistics',
#  '/wiki/Data_analysis',
#  '/wiki/Machine_learning',
#  '#cite_note-Hayashi-3',
#  '/wiki/Mathematics',
#  '/wiki/Statistics',
#  '/wiki/Computer_science',
#  '/wiki/Information_science',
#  '/wiki/Turing_award',
#  '/wiki/Jim_Gray_(computer_scientist)',
#  '/wiki/Empirical_research',
#  '/wiki/Basic_research',
#  '/wiki/Computational_science',
#  '/wiki/Information_explosion',
#  '#cite_note-TansleyTolle2009-4',
#  '#cite_note-BellHey2009-5',
#  '/wiki/American_Statistical_Association',
#  '/wiki/Database',
#  '/wiki/Machine_learning',
#  '/wiki/Distributed_computing',
#  '#cite_note-6',
#  '#Historical_Overview',
#  '#Relationship_to_statistics',
#  '#References',
#  '/w/index.php?title=Data_science&action=edit&section=1',
#  '/wiki/Computer_science',
#  '/wiki/Peter_Naur',
#  '#cite_note-7',
#  '/wiki/Montpellier_2_University',
#  '#cite_note-Escoufier-8',
#  '#cite_note-9',
#  '#cite_note-Hayashi-3',
#  '/wiki/C.F._Jeff_Wu',
#  '#cite_note-cfjwutk-10',
#  '/wiki/University_of_Michigan',
#  '#cite_note-cfjwu01-11',
#  '#cite_note-cfjwutk-10',
#  '#cite_note-cfjwu02-12',
#  '/wiki/Prasanta_Chandra_Mahalanobis',
#  '/wiki/Indian_Statistical_Institute',
#  '/wiki/William_S._Cleveland',
#  '#cite_note-cleveland01-13',
#  '#cite_note-ics12-14',
#  '#cite_note-dsj12-15',
#  '#cite_note-dsj02-16',
#  '#cite_note-jds03-17',
#  '#cite_note-18',
#  '/wiki/Wikipedia:Citation_needed',
#  '/wiki/Jim_Gray_(computer_scientist)',
#  '#cite_note-TansleyTolle2009-4',
#  '#cite_note-BellHey2009-5',
#  '#cite_note-19',
#  '/wiki/Harvard_Business_Review',
#  '#cite_note-Harvard-20',
#  '/wiki/DJ_Patil',
#  '/wiki/Jeff_Hammerbacher',
#  '#cite_note-21',
#  'http://euads.org',
#  '#cite_note-22',
#  '/wiki/General_Assembly_(school)',
#  '/wiki/The_Data_Incubator',
#  '#cite_note-23',
#  '/wiki/American_Statistical_Association',
#  '#cite_note-ASA-24',
#  '#cite_note-25',
#  'http://www.gfkl.org/welcome/',
#  '/wiki/University_of_Essex',
#  '/w/index.php?title=Data_science&action=edit&section=2',
#  '/wiki/American_Statistical_Association',
#  '/wiki/Nate_Silver',
#  '#cite_note-NateSilver-26',
#  '/wiki/The_Wall_Street_Journal',
#  '/wiki/Computer_science',
#  '/wiki/Interdisciplinarity',
#  '/wiki/Methodology',
#  '/wiki/Academy',
#  '/wiki/Industry',
#  '/wiki/Discipline_(academia)',
#  '#cite_note-:1-27',
#  '/wiki/New_York_University',
#  '/wiki/NYU_Stern_Center_for_Business_and_Human_Rights',
#  '#cite_note-:1-27',
#  '/wiki/Discipline_(academia)',
#  '/wiki/Data_set',
#  '/wiki/Pattern_recognition',
#  '/wiki/Predictive_modelling',
#  '#cite_note-:0-1',
#  '/wiki/Analytics',
#  '/wiki/Applied_science',
#  '/wiki/Theory',
#  '/wiki/Health_science',
#  '/wiki/Social_science',
#  '#cite_note-:0-1',
#  '/wiki/David_Donoho',
#  '#cite_note-:2-28',
#  '/wiki/Big_data',
#  '#cite_note-:2-28',
#  '/wiki/Computing',
#  '#cite_note-:2-28',
#  '/wiki/Graduate_school',
#  '/wiki/Graduate_school',
#  '/wiki/Analytics',
#  '#cite_note-:2-28',
#  '#cite_note-29',
#  '/wiki/Statistician',
#  '/wiki/David_Donoho',
#  '#cite_note-:2-28',
#  '#cite_note-30',
#  '/wiki/Statistician',
#  '/wiki/Statistics',
#  '/wiki/Open_science',
#  '/wiki/Academic_publishing',
#  '#cite_note-:2-28',
#  '/wiki/National_Institutes_of_Health',
#  '#cite_note-31',
#  '/wiki/Academic_journal',
#  '#cite_note-32',
#  '#cite_note-33',
#  '/wiki/Statistical_theory',
#  '/wiki/Paradigm',
#  '#cite_note-:2-28',
#  '#cite_note-:2-28',
#  '/w/index.php?title=Data_science&action=edit&section=3',
#  '#cite_ref-:0_1-0',
#  '#cite_ref-:0_1-1',
#  '#cite_ref-:0_1-2',
#  'http://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext',
#  '/wiki/Digital_object_identifier',
#  'https://doi.org/10.1145%2F2500499',
#  'https://web.archive.org/web/20141109113411/http://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext',
#  '#cite_ref-2',
#  '/wiki/Jeffrey_T._Leek',
#  'http://simplystatistics.org/2013/12/12/the-key-word-in-data-science-is-not-data-it-is-science/',
#  'https://web.archive.org/web/20140102194117/http://simplystatistics.org/2013/12/12/the-key-word-in-data-science-is-not-data-it-is-science/',
#  '#cite_ref-Hayashi_3-0',
#  '#cite_ref-Hayashi_3-1',
#  'https://www.springer.com/book/9784431702085',
#  '/wiki/Digital_object_identifier',
#  'https://doi.org/10.1007%2F978-4-431-65950-1_3',
#  '/wiki/International_Standard_Book_Number',
#  '/wiki/Special:BookSources/9784431702085',
#  '#cite_ref-TansleyTolle2009_4-0',
#  '#cite_ref-TansleyTolle2009_4-1',
#  'https://books.google.com/books?id=oGs_AQAAIAAJ',
#  '/wiki/International_Standard_Book_Number',
#  '/wiki/Special:BookSources/978-0-9825442-0-4',
#  'https://web.archive.org/web/20170320193019/https://books.google.com/books?id=oGs_AQAAIAAJ',
#  '#cite_ref-BellHey2009_5-0',
#  '#cite_ref-BellHey2009_5-1',
#  '/wiki/Digital_object_identifier',
#  'https://doi.org/10.1126%2Fscience.1170411',
#  '/wiki/International_Standard_Serial_Number',
#  '//www.worldcat.org/issn/0036-8075',
#  '/wiki/PubMed_Identifier',
#  '//pubmed.ncbi.nlm.nih.gov/19265007',
#  '#cite_ref-6',
#  'https://magazine.amstat.org/blog/2015/10/01/asa-statement-on-the-role-of-statistics-in-data-science/',
#  '/wiki/American_Statistical_Association',
#  'https://web.archive.org/web/20190620184935/https://magazine.amstat.org/blog/2015/10/01/asa-statement-on-the-role-of-statistics-in-data-science/',
#  '#cite_ref-7',
#  '/wiki/Digital_object_identifier',
#  'https://doi.org/10.1145%2F365719.366510',
#  '#cite_ref-Escoufier_8-0',
#  '/wiki/International_Standard_Book_Number',
#  '/wiki/Special:BookSources/0-12-241770-4',
#  '#cite_ref-9',
#  'https://www.forbes.com/sites/gilpress/2013/05/28/a-very-short-history-of-data-science/',
#  'https://web.archive.org/web/20170911223224/https://www.forbes.com/sites/gilpress/2013/05/28/a-very-short-history-of-data-science/',
#  '#cite_ref-cfjwutk_10-0',
#  '#cite_ref-cfjwutk_10-1',
#  'http://www2.isye.gatech.edu/~jeffwu/presentations/datascience.pdf',
#  'https://web.archive.org/web/20141014022300/http://www2.isye.gatech.edu/~jeffwu/presentations/datascience.pdf',
#  '#cite_ref-cfjwu01_11-0',
#  'http://ur.umich.edu/9899/Nov09_98/4.htm',
#  'https://web.archive.org/web/20131029200232/http://ur.umich.edu/9899/Nov09_98/4.htm',
#  '#cite_ref-cfjwu02_12-0',
#  'https://web.archive.org/web/20131029191813/http://www.isical.ac.in/~statmath/html/pcm/pcm_recent.html',
#  'http://www.isical.ac.in/~statmath/html/pcm/pcm_recent.html',
#  '#cite_ref-cleveland01_13-0',
#  'https://pdfs.semanticscholar.org/915c/d8e2b39eb02723553913d592b2237d4d9960.pdf',
#  'https://web.archive.org/web/20180215023354/https://pdfs.semanticscholar.org/915c/d8e2b39eb02723553913d592b2237d4d9960.pdf',
#  '/wiki/Wayback_Machine',
#  '#cite_ref-ics12_14-0',
#  'http://www.codata.org/',
#  'https://web.archive.org/web/20080511160948/http://www.codata.org/',
#  '/wiki/Wayback_Machine',
#  '#cite_ref-dsj12_15-0',
#  'http://www.jstage.jst.go.jp/browse/dsj/_vols',
#  'https://web.archive.org/web/20120403153707/http://www.jstage.jst.go.jp/browse/dsj/_vols',
#  '/wiki/Wayback_Machine',
#  '#cite_ref-dsj02_16-0',
#  'http://www.jstage.jst.go.jp/browse/dsj/1/0/_contents',
#  'https://web.archive.org/web/20090609022730/http://www.jstage.jst.go.jp/browse/dsj/1/0/_contents',
#  '/wiki/Wayback_Machine',
#  '#cite_ref-jds03_17-0',
#  'http://www.jds-online.com/v1-1',
#  'https://web.archive.org/web/20120822033955/http://www.jds-online.com/v1-1',
#  '/wiki/Wayback_Machine',
#  '#cite_ref-18',
#  'http://www.nsf.gov/pubs/2005/nsb0540/',
#  'https://web.archive.org/web/20130703121219/http://www.nsf.gov/pubs/2005/nsb0540/',
#  '#cite_ref-19',
#  'https://www.nytimes.com/2009/12/15/science/15books.html',
#  '/wiki/International_Standard_Serial_Number',
#  '//www.worldcat.org/issn/0362-4331',
#  'https://web.archive.org/web/20180426153402/https://www.nytimes.com/2009/12/15/science/15books.html',
#  '#cite_ref-Harvard_20-0',
#  '/wiki/Thomas_H._Davenport',
#  '/wiki/DJ_Patil',
#  'https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century/',
#  '/wiki/Harvard_Business_Review',
#  'https://web.archive.org/web/20160202061421/https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century/',
#  '#cite_ref-21',
#  'http://www.dsaa.co',
#  'https://web.archive.org/web/20180323043716/http://dsaa.co/',
#  '#cite_ref-22',
#  'https://web.archive.org/web/20170329172857/http://datamining.it.uts.edu.au/conferences/dsaa14/',
#  'http://datamining.it.uts.edu.au/conferences/dsaa14/',
#  '#cite_ref-23',
#  'https://venturebeat.com/2014/04/15/ny-gets-new-bootcamp-for-data-scientists-its-free-but-harder-to-get-into-than-harvard/',
#  'https://web.archive.org/web/20160215235820/http://venturebeat.com/2014/04/15/ny-gets-new-bootcamp-for-data-scientists-its-free-but-harder-to-get-into-than-harvard/',
#  '#cite_ref-ASA_24-0',
#  'https://web.archive.org/web/20170205101231/http://magazine.amstat.org/blog/2016/06/01/datascience-2/',
#  '/wiki/American_Statistical_Association',
#  'http://magazine.amstat.org/blog/2016/06/01/datascience-2/',
#  '#cite_ref-25',
#  'https://www.springer.com/41060',
#  '#cite_ref-NateSilver_26-0',
#  'http://www.statisticsviews.com/details/feature/5133141/Nate-Silver-What-I-need-from-statisticians.html',
#  'https://web.archive.org/web/20130823091106/http://www.statisticsviews.com/details/feature/5133141/Nate-Silver-What-I-need-from-statisticians.html',
#  '#cite_ref-:1_27-0',
#  '#cite_ref-:1_27-1',
#  'https://blogs.wsj.com/cio/2014/05/02/why-do-we-need-data-science-when-weve-had-statistics-for-centuries/',
#  'https://web.archive.org/web/20171124155559/https://blogs.wsj.com/cio/2014/05/02/why-do-we-need-data-science-when-weve-had-statistics-for-centuries/',
#  '#cite_ref-:2_28-0',
#  '#cite_ref-:2_28-1',
#  '#cite_ref-:2_28-2',
#  '#cite_ref-:2_28-3',
#  '#cite_ref-:2_28-4',
#  '#cite_ref-:2_28-5',
#  '#cite_ref-:2_28-6',
#  '#cite_ref-:2_28-7',
#  'http://courses.csail.mit.edu/18.337/2015/docs/50YearsDataScience.pdf',
#  'https://web.archive.org/web/20180619003326/http://courses.csail.mit.edu/18.337/2015/docs/50YearsDataScience.pdf',
#  '#cite_ref-29',
#  'https://books.google.com/books?id=zdBXAQAAQBAJ&printsec=frontcover#v=onepage&q=%22data%20science%22&f=false',
#  '#cite_ref-30',
#  '/wiki/Digital_object_identifier',
#  'https://doi.org/10.1007%2FBF00141776',
#  '/wiki/International_Standard_Serial_Number',
#  '//www.worldcat.org/issn/0960-3174',
#  '#cite_ref-31',
#  '//www.ncbi.nlm.nih.gov/pmc/articles/PMC4058759',
#  '/wiki/Digital_object_identifier',
#  'https://doi.org/10.1038%2F505612a',
#  '/wiki/International_Standard_Serial_Number',
#  '//www.worldcat.org/issn/0028-0836',
#  '/wiki/PubMed_Central',
#  '//www.ncbi.nlm.nih.gov/pmc/articles/PMC4058759',
#  '/wiki/PubMed_Identifier',
#  '//pubmed.ncbi.nlm.nih.gov/24482835',
#  '#cite_ref-32',
#  '/wiki/Digital_object_identifier',
#  'https://doi.org/10.1126%2Fscience.1250475',
#  '/wiki/International_Standard_Serial_Number',
#  '//www.worldcat.org/issn/0036-8075',
#  '/wiki/PubMed_Identifier',
#  '//pubmed.ncbi.nlm.nih.gov/24436391',
#  '#cite_ref-33',
#  '/wiki/Digital_object_identifier',
#  'https://doi.org/10.1093%2Fbiostatistics%2Fkxp014',
#  '/wiki/International_Standard_Serial_Number',
#  '//www.worldcat.org/issn/1465-4644',
#  '/wiki/PubMed_Identifier',
#  '//pubmed.ncbi.nlm.nih.gov/19535325',
#  'https://en.wikipedia.org/w/index.php?title=Data_science&oldid=946667548',
#  '/wiki/Help:Category',
#  '/wiki/Category:Information_science',
#  '/wiki/Category:Computer_occupations',
#  '/wiki/Category:Computational_fields_of_study',
#  '/wiki/Category:Data_analysis',
#  '/wiki/Category:Webarchive_template_wayback_links',
#  '/wiki/Category:Use_dmy_dates_from_December_2012',
#  '/wiki/Category:All_articles_with_unsourced_statements',
#  '/wiki/Category:Articles_with_unsourced_statements_from_April_2018',
#  '/wiki/Special:MyTalk',
#  '/wiki/Special:MyContributions',
#  '/w/index.php?title=Special:CreateAccount&returnto=Data+science',
#  '/w/index.php?title=Special:UserLogin&returnto=Data+science',
#  '/wiki/Data_science',
#  '/wiki/Talk:Data_science',
#  '/wiki/Data_science',
#  '/w/index.php?title=Data_science&action=edit',
#  '/w/index.php?title=Data_science&action=history',
#  '/wiki/Main_Page',
#  '/wiki/Main_Page',
#  '/wiki/Wikipedia:Contents',
#  '/wiki/Wikipedia:Featured_content',
#  '/wiki/Portal:Current_events',
#  '/wiki/Special:Random',
#  'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en',
#  '//shop.wikimedia.org',
#  '/wiki/Help:Contents',
#  '/wiki/Wikipedia:About',
#  '/wiki/Wikipedia:Community_portal',
#  '/wiki/Special:RecentChanges',
#  '//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  '/wiki/Special:WhatLinksHere/Data_science',
#  '/wiki/Special:RecentChangesLinked/Data_science',
#  '/wiki/Wikipedia:File_Upload_Wizard',
#  '/wiki/Special:SpecialPages',
#  '/w/index.php?title=Data_science&oldid=946667548',
#  '/w/index.php?title=Data_science&action=info',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q2374463',
#  '/w/index.php?title=Special:CiteThisPage&page=Data_science&id=946667548&wpFormIdentifier=titleform',
#  'https://commons.wikimedia.org/wiki/Category:Data_science',
#  '/w/index.php?title=Special:Book&bookcmd=book_creator&referer=Data+science',
#  '/w/index.php?title=Special:ElectronPdf&page=Data+science&action=show-download-screen',
#  '/w/index.php?title=Data_science&printable=yes',
#  'https://ar.wikipedia.org/wiki/%D8%B9%D9%84%D9%85_%D8%A7%D9%84%D8%A8%D9%8A%D8%A7%D9%86%D8%A7%D8%AA',
#  'https://az.wikipedia.org/wiki/Veril%C9%99nl%C9%99r_elmi_(Data_Science)',
#  'https://ca.wikipedia.org/wiki/Ci%C3%A8ncia_de_les_dades',
#  'https://cs.wikipedia.org/wiki/Data_science',
#  'https://de.wikipedia.org/wiki/Data_Science',
#  'https://el.wikipedia.org/wiki/%CE%95%CF%80%CE%B9%CF%83%CF%84%CE%AE%CE%BC%CE%B7_%CE%B4%CE%B5%CE%B4%CE%BF%CE%BC%CE%AD%CE%BD%CF%89%CE%BD',
#  'https://es.wikipedia.org/wiki/Ciencia_de_datos',
#  'https://eu.wikipedia.org/wiki/Datu_zientzia',
#  'https://fa.wikipedia.org/wiki/%D8%B9%D9%84%D9%85_%D8%AF%D8%A7%D8%AF%D9%87%E2%80%8C%D9%87%D8%A7',
#  'https://fr.wikipedia.org/wiki/Science_des_donn%C3%A9es',
#  'https://ko.wikipedia.org/wiki/%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%82%AC%EC%9D%B4%EC%96%B8%EC%8A%A4',
#  'https://hy.wikipedia.org/wiki/%D5%8F%D5%BE%D5%B5%D5%A1%D5%AC%D5%B6%D5%A5%D6%80%D5%AB_%D5%A3%D5%AB%D5%BF%D5%B8%D6%82%D5%A9%D5%B5%D5%B8%D6%82%D5%B6',
#  'https://hi.wikipedia.org/wiki/%E0%A4%86%E0%A4%81%E0%A4%95%E0%A4%A1%E0%A4%BC%E0%A4%BE_%E0%A4%B5%E0%A4%BF%E0%A4%9C%E0%A5%8D%E0%A4%9E%E0%A4%BE%E0%A4%A8',
#  'https://id.wikipedia.org/wiki/Ilmu_data',
#  'https://it.wikipedia.org/wiki/Scienza_dei_dati',
#  'https://he.wikipedia.org/wiki/%D7%9E%D7%93%D7%A2_%D7%94%D7%A0%D7%AA%D7%95%D7%A0%D7%99%D7%9D',
#  'https://lv.wikipedia.org/wiki/Datu_m%C4%81c%C4%ABba',
#  'https://ms.wikipedia.org/wiki/Sains_data',
#  'https://my.wikipedia.org/wiki/%E1%80%A1%E1%80%81%E1%80%BB%E1%80%80%E1%80%BA%E1%80%A1%E1%80%9C%E1%80%80%E1%80%BA%E1%80%9E%E1%80%AD%E1%80%95%E1%80%B9%E1%80%95%E1%80%B6%E1%80%95%E1%80%8A%E1%80%AC',
#  'https://nl.wikipedia.org/wiki/Datawetenschap',
#  'https://ja.wikipedia.org/wiki/%E3%83%87%E3%83%BC%E3%82%BF%E3%82%B5%E3%82%A4%E3%82%A8%E3%83%B3%E3%82%B9',
#  'https://pt.wikipedia.org/wiki/Ci%C3%AAncia_de_dados',
#  'https://ru.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%BE_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#  'https://simple.wikipedia.org/wiki/Data_science',
#  'https://fi.wikipedia.org/wiki/Datatiede',
#  'https://ta.wikipedia.org/wiki/%E0%AE%A4%E0%AE%B0%E0%AE%B5%E0%AF%81_%E0%AE%85%E0%AE%B1%E0%AE%BF%E0%AE%B5%E0%AE%BF%E0%AE%AF%E0%AE%B2%E0%AF%8D',
#  'https://tr.wikipedia.org/wiki/Veri_bilimi',
#  'https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%BF%D1%80%D0%BE_%D0%B4%D0%B0%D0%BD%D1%96',
#  'https://vi.wikipedia.org/wiki/Khoa_h%E1%BB%8Dc_d%E1%BB%AF_li%E1%BB%87u',
#  'https://zh-yue.wikipedia.org/wiki/%E6%95%B8%E6%93%9A%E7%A7%91%E5%AD%B8',
#  'https://zh.wikipedia.org/wiki/%E6%95%B0%E6%8D%AE%E7%A7%91%E5%AD%A6',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q2374463#sitelinks-wikipedia',
#  '//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#  '//creativecommons.org/licenses/by-sa/3.0/',
#  '//foundation.wikimedia.org/wiki/Terms_of_Use',
#  '//foundation.wikimedia.org/wiki/Privacy_policy',
#  '//www.wikimediafoundation.org/',
#  'https://foundation.wikimedia.org/wiki/Privacy_policy',
#  '/wiki/Wikipedia:About',
#  '/wiki/Wikipedia:General_disclaimer',
#  '//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  'https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute',
#  'https://stats.wikimedia.org/#/en.wikipedia.org',
#  'https://foundation.wikimedia.org/wiki/Cookie_statement',
#  '//en.m.wikipedia.org/w/index.php?title=Data_science&mobileaction=toggle_view_mobile',
#  'https://wikimediafoundation.org/',
#  'https://www.mediawiki.org/']

# %% [markdown]
# ## Step 3: Use list comprehensions with conditions to clean the link list.
#
# There are two types of links, absolute and relative. Absolute links have the full URL and begin with http while relative links begin with a forward slash (/) and point to an internal page within the wikipedia.org domain. Clean the respective types of URLs as follows.
#
# - Absolute Links: Create a list of these and remove any that contain a percentage sign (%).
# - Relativel Links: Create a list of these, add the domain to the link so that you have the full URL, and remove any that contain a percentage sign (%).
# - Combine the list of absolute and relative links and ensure there are no duplicates.

# %%
domain = 'http://wikipedia.org'

# %%
response2 = requests.get(domain).content
soup2 = bs(response2)
all_links = [link['href'] for link in soup2.find_all('a', href=True)]

# %%
absolute_links = [link for link in all_links if link.startswith('http') and '%' not in link]
relative_links = [domain + link for link in all_links if link.startswith('/') and '%' not in link]
combine_links = absolute_links
combine_links.extend(x for x in relative_links if x not in combine_links)
combine_links
# Out:
# ['https://en.wikipedia.org/wiki/List_of_Wikipedia_mobile_applications',
#  'https://creativecommons.org/licenses/by-sa/3.0/',
#  'http://wikipedia.org//en.wikipedia.org/',
#  'http://wikipedia.org//es.wikipedia.org/',
#  'http://wikipedia.org//ja.wikipedia.org/',
#  'http://wikipedia.org//de.wikipedia.org/',
#  'http://wikipedia.org//ru.wikipedia.org/',
#  'http://wikipedia.org//fr.wikipedia.org/',
#  'http://wikipedia.org//it.wikipedia.org/',
#  'http://wikipedia.org//zh.wikipedia.org/',
#  'http://wikipedia.org//pt.wikipedia.org/',
#  'http://wikipedia.org//pl.wikipedia.org/',
#  'http://wikipedia.org//ar.wikipedia.org/',
#  'http://wikipedia.org//nl.wikipedia.org/',
#  'http://wikipedia.org//ceb.wikipedia.org/',
#  'http://wikipedia.org//sv.wikipedia.org/',
#  'http://wikipedia.org//vi.wikipedia.org/',
#  'http://wikipedia.org//war.wikipedia.org/',
#  'http://wikipedia.org//ast.wikipedia.org/',
#  'http://wikipedia.org//az.wikipedia.org/',
#  'http://wikipedia.org//bg.wikipedia.org/',
#  'http://wikipedia.org//zh-min-nan.wikipedia.org/',
#  'http://wikipedia.org//be.wikipedia.org/',
#  'http://wikipedia.org//ca.wikipedia.org/',
#  'http://wikipedia.org//cs.wikipedia.org/',
#  'http://wikipedia.org//da.wikipedia.org/',
#  'http://wikipedia.org//et.wikipedia.org/',
#  'http://wikipedia.org//el.wikipedia.org/',
#  'http://wikipedia.org//eo.wikipedia.org/',
#  'http://wikipedia.org//eu.wikipedia.org/',
#  'http://wikipedia.org//fa.wikipedia.org/',
#  'http://wikipedia.org//gl.wikipedia.org/',
#  'http://wikipedia.org//hy.wikipedia.org/',
#  'http://wikipedia.org//hi.wikipedia.org/',
#  'http://wikipedia.org//hr.wikipedia.org/',
#  'http://wikipedia.org//id.wikipedia.org/',
#  'http://wikipedia.org//he.wikipedia.org/',
#  'http://wikipedia.org//ka.wikipedia.org/',
#  'http://wikipedia.org//la.wikipedia.org/',
#  'http://wikipedia.org//lv.wikipedia.org/',
#  'http://wikipedia.org//lt.wikipedia.org/',
#  'http://wikipedia.org//hu.wikipedia.org/',
#  'http://wikipedia.org//mk.wikipedia.org/',
#  'http://wikipedia.org//arz.wikipedia.org/',
#  'http://wikipedia.org//ms.wikipedia.org/',
#  'http://wikipedia.org//min.wikipedia.org/',
#  'http://wikipedia.org//no.wikipedia.org/',
#  'http://wikipedia.org//nn.wikipedia.org/',
#  'http://wikipedia.org//ce.wikipedia.org/',
#  'http://wikipedia.org//uz.wikipedia.org/',
#  'http://wikipedia.org//kk.wikipedia.org/',
#  'http://wikipedia.org//ro.wikipedia.org/',
#  'http://wikipedia.org//cy.wikipedia.org/',
#  'http://wikipedia.org//simple.wikipedia.org/',
#  'http://wikipedia.org//sk.wikipedia.org/',
#  'http://wikipedia.org//sl.wikipedia.org/',
#  'http://wikipedia.org//sr.wikipedia.org/',
#  'http://wikipedia.org//sh.wikipedia.org/',
#  'http://wikipedia.org//fi.wikipedia.org/',
#  'http://wikipedia.org//ta.wikipedia.org/',
#  'http://wikipedia.org//th.wikipedia.org/',
#  'http://wikipedia.org//tg.wikipedia.org/',
#  'http://wikipedia.org//azb.wikipedia.org/',
#  'http://wikipedia.org//tr.wikipedia.org/',
#  'http://wikipedia.org//uk.wikipedia.org/',
#  'http://wikipedia.org//ur.wikipedia.org/',
#  'http://wikipedia.org//vo.wikipedia.org/',
#  'http://wikipedia.org//ko.wikipedia.org/',
#  'http://wikipedia.org//ace.wikipedia.org/',
#  'http://wikipedia.org//af.wikipedia.org/',
#  'http://wikipedia.org//als.wikipedia.org/',
#  'http://wikipedia.org//am.wikipedia.org/',
#  'http://wikipedia.org//an.wikipedia.org/',
#  'http://wikipedia.org//bn.wikipedia.org/',
#  'http://wikipedia.org//map-bms.wikipedia.org/',
#  'http://wikipedia.org//ba.wikipedia.org/',
#  'http://wikipedia.org//be-tarask.wikipedia.org/',
#  'http://wikipedia.org//bpy.wikipedia.org/',
#  'http://wikipedia.org//bar.wikipedia.org/',
#  'http://wikipedia.org//bs.wikipedia.org/',
#  'http://wikipedia.org//br.wikipedia.org/',
#  'http://wikipedia.org//cv.wikipedia.org/',
#  'http://wikipedia.org//nv.wikipedia.org/',
#  'http://wikipedia.org//eml.wikipedia.org/',
#  'http://wikipedia.org//fo.wikipedia.org/',
#  'http://wikipedia.org//fy.wikipedia.org/',
#  'http://wikipedia.org//ga.wikipedia.org/',
#  'http://wikipedia.org//gd.wikipedia.org/',
#  'http://wikipedia.org//gu.wikipedia.org/',
#  'http://wikipedia.org//hsb.wikipedia.org/',
#  'http://wikipedia.org//io.wikipedia.org/',
#  'http://wikipedia.org//ilo.wikipedia.org/',
#  'http://wikipedia.org//ia.wikipedia.org/',
#  'http://wikipedia.org//os.wikipedia.org/',
#  'http://wikipedia.org//is.wikipedia.org/',
#  'http://wikipedia.org//jv.wikipedia.org/',
#  'http://wikipedia.org//kn.wikipedia.org/',
#  'http://wikipedia.org//ht.wikipedia.org/',
#  'http://wikipedia.org//ku.wikipedia.org/',
#  'http://wikipedia.org//ckb.wikipedia.org/',
#  'http://wikipedia.org//ky.wikipedia.org/',
#  'http://wikipedia.org//mrj.wikipedia.org/',
#  'http://wikipedia.org//lb.wikipedia.org/',
#  'http://wikipedia.org//li.wikipedia.org/',
#  'http://wikipedia.org//lmo.wikipedia.org/',
#  'http://wikipedia.org//mai.wikipedia.org/',
#  'http://wikipedia.org//mg.wikipedia.org/',
#  'http://wikipedia.org//ml.wikipedia.org/',
#  'http://wikipedia.org//zh-classical.wikipedia.org/',
#  'http://wikipedia.org//mr.wikipedia.org/',
#  'http://wikipedia.org//xmf.wikipedia.org/',
#  'http://wikipedia.org//mzn.wikipedia.org/',
#  'http://wikipedia.org//cdo.wikipedia.org/',
#  'http://wikipedia.org//mn.wikipedia.org/',
#  'http://wikipedia.org//my.wikipedia.org/',
#  'http://wikipedia.org//new.wikipedia.org/',
#  'http://wikipedia.org//ne.wikipedia.org/',
#  'http://wikipedia.org//nap.wikipedia.org/',
#  'http://wikipedia.org//frr.wikipedia.org/',
#  'http://wikipedia.org//oc.wikipedia.org/',
#  'http://wikipedia.org//mhr.wikipedia.org/',
#  'http://wikipedia.org//or.wikipedia.org/',
#  'http://wikipedia.org//pa.wikipedia.org/',
#  'http://wikipedia.org//pnb.wikipedia.org/',
#  'http://wikipedia.org//ps.wikipedia.org/',
#  'http://wikipedia.org//pms.wikipedia.org/',
#  'http://wikipedia.org//nds.wikipedia.org/',
#  'http://wikipedia.org//qu.wikipedia.org/',
#  'http://wikipedia.org//sa.wikipedia.org/',
#  'http://wikipedia.org//sah.wikipedia.org/',
#  'http://wikipedia.org//sco.wikipedia.org/',
#  'http://wikipedia.org//sq.wikipedia.org/',
#  'http://wikipedia.org//scn.wikipedia.org/',
#  'http://wikipedia.org//si.wikipedia.org/',
#  'http://wikipedia.org//sd.wikipedia.org/',
#  'http://wikipedia.org//szl.wikipedia.org/',
#  'http://wikipedia.org//su.wikipedia.org/',
#  'http://wikipedia.org//sw.wikipedia.org/',
#  'http://wikipedia.org//tl.wikipedia.org/',
#  'http://wikipedia.org//tt.wikipedia.org/',
#  'http://wikipedia.org//te.wikipedia.org/',
#  'http://wikipedia.org//bug.wikipedia.org/',
#  'http://wikipedia.org//vec.wikipedia.org/',
#  'http://wikipedia.org//wa.wikipedia.org/',
#  'http://wikipedia.org//wuu.wikipedia.org/',
#  'http://wikipedia.org//yi.wikipedia.org/',
#  'http://wikipedia.org//yo.wikipedia.org/',
#  'http://wikipedia.org//zh-yue.wikipedia.org/',
#  'http://wikipedia.org//diq.wikipedia.org/',
#  'http://wikipedia.org//bat-smg.wikipedia.org/',
#  'http://wikipedia.org//kbd.wikipedia.org/',
#  'http://wikipedia.org//ang.wikipedia.org/',
#  'http://wikipedia.org//ab.wikipedia.org/',
#  'http://wikipedia.org//hyw.wikipedia.org/',
#  'http://wikipedia.org//roa-rup.wikipedia.org/',
#  'http://wikipedia.org//frp.wikipedia.org/',
#  'http://wikipedia.org//ig.wikipedia.org/',
#  'http://wikipedia.org//arc.wikipedia.org/',
#  'http://wikipedia.org//gn.wikipedia.org/',
#  'http://wikipedia.org//av.wikipedia.org/',
#  'http://wikipedia.org//ay.wikipedia.org/',
#  'http://wikipedia.org//bjn.wikipedia.org/',
#  'http://wikipedia.org//bh.wikipedia.org/',
#  'http://wikipedia.org//bcl.wikipedia.org/',
#  'http://wikipedia.org//bi.wikipedia.org/',
#  'http://wikipedia.org//bo.wikipedia.org/',
#  'http://wikipedia.org//bxr.wikipedia.org/',
#  'http://wikipedia.org//cbk-zam.wikipedia.org/',
#  'http://wikipedia.org//co.wikipedia.org/',
#  'http://wikipedia.org//za.wikipedia.org/',
#  'http://wikipedia.org//se.wikipedia.org/',
#  'http://wikipedia.org//pdc.wikipedia.org/',
#  'http://wikipedia.org//dsb.wikipedia.org/',
#  'http://wikipedia.org//myv.wikipedia.org/',
#  'http://wikipedia.org//ext.wikipedia.org/',
#  'http://wikipedia.org//hif.wikipedia.org/',
#  'http://wikipedia.org//fur.wikipedia.org/',
#  'http://wikipedia.org//gv.wikipedia.org/',
#  'http://wikipedia.org//gag.wikipedia.org/',
#  'http://wikipedia.org//ki.wikipedia.org/',
#  'http://wikipedia.org//glk.wikipedia.org/',
#  'http://wikipedia.org//gan.wikipedia.org/',
#  'http://wikipedia.org//hak.wikipedia.org/',
#  'http://wikipedia.org//xal.wikipedia.org/',
#  'http://wikipedia.org//ha.wikipedia.org/',
#  'http://wikipedia.org//haw.wikipedia.org/',
#  'http://wikipedia.org//ie.wikipedia.org/',
#  'http://wikipedia.org//kl.wikipedia.org/',
#  'http://wikipedia.org//pam.wikipedia.org/',
#  'http://wikipedia.org//csb.wikipedia.org/',
#  'http://wikipedia.org//kw.wikipedia.org/',
#  'http://wikipedia.org//km.wikipedia.org/',
#  'http://wikipedia.org//rw.wikipedia.org/',
#  'http://wikipedia.org//kv.wikipedia.org/',
#  'http://wikipedia.org//kg.wikipedia.org/',
#  'http://wikipedia.org//gom.wikipedia.org/',
#  'http://wikipedia.org//gcr.wikipedia.org/',
#  'http://wikipedia.org//lo.wikipedia.org/',
#  'http://wikipedia.org//lad.wikipedia.org/',
#  'http://wikipedia.org//lbe.wikipedia.org/',
#  'http://wikipedia.org//lez.wikipedia.org/',
#  'http://wikipedia.org//ln.wikipedia.org/',
#  'http://wikipedia.org//jbo.wikipedia.org/',
#  'http://wikipedia.org//lrc.wikipedia.org/',
#  'http://wikipedia.org//lg.wikipedia.org/',
#  'http://wikipedia.org//lij.wikipedia.org/',
#  'http://wikipedia.org//mt.wikipedia.org/',
#  'http://wikipedia.org//ty.wikipedia.org/',
#  'http://wikipedia.org//mi.wikipedia.org/',
#  'http://wikipedia.org//mwl.wikipedia.org/',
#  'http://wikipedia.org//mdf.wikipedia.org/',
#  'http://wikipedia.org//nah.wikipedia.org/',
#  'http://wikipedia.org//na.wikipedia.org/',
#  'http://wikipedia.org//nds-nl.wikipedia.org/',
#  'http://wikipedia.org//nrm.wikipedia.org/',
#  'http://wikipedia.org//nov.wikipedia.org/',
#  'http://wikipedia.org//as.wikipedia.org/',
#  'http://wikipedia.org//pi.wikipedia.org/',
#  'http://wikipedia.org//pag.wikipedia.org/',
#  'http://wikipedia.org//pap.wikipedia.org/',
#  'http://wikipedia.org//koi.wikipedia.org/',
#  'http://wikipedia.org//pfl.wikipedia.org/',
#  'http://wikipedia.org//pcd.wikipedia.org/',
#  'http://wikipedia.org//krc.wikipedia.org/',
#  'http://wikipedia.org//kaa.wikipedia.org/',
#  'http://wikipedia.org//crh.wikipedia.org/',
#  'http://wikipedia.org//ksh.wikipedia.org/',
#  'http://wikipedia.org//rm.wikipedia.org/',
#  'http://wikipedia.org//rue.wikipedia.org/',
#  'http://wikipedia.org//sc.wikipedia.org/',
#  'http://wikipedia.org//stq.wikipedia.org/',
#  'http://wikipedia.org//nso.wikipedia.org/',
#  'http://wikipedia.org//sn.wikipedia.org/',
#  'http://wikipedia.org//so.wikipedia.org/',
#  'http://wikipedia.org//srn.wikipedia.org/',
#  'http://wikipedia.org//kab.wikipedia.org/',
#  'http://wikipedia.org//roa-tara.wikipedia.org/',
#  'http://wikipedia.org//tet.wikipedia.org/',
#  'http://wikipedia.org//tpi.wikipedia.org/',
#  'http://wikipedia.org//to.wikipedia.org/',
#  'http://wikipedia.org//tk.wikipedia.org/',
#  'http://wikipedia.org//tyv.wikipedia.org/',
#  'http://wikipedia.org//udm.wikipedia.org/',
#  'http://wikipedia.org//ug.wikipedia.org/',
#  'http://wikipedia.org//vep.wikipedia.org/',
#  'http://wikipedia.org//fiu-vro.wikipedia.org/',
#  'http://wikipedia.org//vls.wikipedia.org/',
#  'http://wikipedia.org//wo.wikipedia.org/',
#  'http://wikipedia.org//xh.wikipedia.org/',
#  'http://wikipedia.org//zea.wikipedia.org/',
#  'http://wikipedia.org//zu.wikipedia.org/',
#  'http://wikipedia.org//dv.wikipedia.org/',
#  'http://wikipedia.org//ak.wikipedia.org/',
#  'http://wikipedia.org//bm.wikipedia.org/',
#  'http://wikipedia.org//ch.wikipedia.org/',
#  'http://wikipedia.org//ny.wikipedia.org/',
#  'http://wikipedia.org//ee.wikipedia.org/',
#  'http://wikipedia.org//ff.wikipedia.org/',
#  'http://wikipedia.org//got.wikipedia.org/',
#  'http://wikipedia.org//iu.wikipedia.org/',
#  'http://wikipedia.org//ik.wikipedia.org/',
#  'http://wikipedia.org//ks.wikipedia.org/',
#  'http://wikipedia.org//ltg.wikipedia.org/',
#  'http://wikipedia.org//fj.wikipedia.org/',
#  'http://wikipedia.org//cr.wikipedia.org/',
#  'http://wikipedia.org//pih.wikipedia.org/',
#  'http://wikipedia.org//om.wikipedia.org/',
#  'http://wikipedia.org//pnt.wikipedia.org/',
#  'http://wikipedia.org//dz.wikipedia.org/',
#  'http://wikipedia.org//rmy.wikipedia.org/',
#  'http://wikipedia.org//rn.wikipedia.org/',
#  'http://wikipedia.org//sm.wikipedia.org/',
#  'http://wikipedia.org//sg.wikipedia.org/',
#  'http://wikipedia.org//st.wikipedia.org/',
#  'http://wikipedia.org//tn.wikipedia.org/',
#  'http://wikipedia.org//cu.wikipedia.org/',
#  'http://wikipedia.org//ss.wikipedia.org/',
#  'http://wikipedia.org//chr.wikipedia.org/',
#  'http://wikipedia.org//chy.wikipedia.org/',
#  'http://wikipedia.org//ve.wikipedia.org/',
#  'http://wikipedia.org//ts.wikipedia.org/',
#  'http://wikipedia.org//tum.wikipedia.org/',
#  'http://wikipedia.org//tw.wikipedia.org/',
#  'http://wikipedia.org//ti.wikipedia.org/',
#  'http://wikipedia.org//nqo.wikipedia.org/',
#  'http://wikipedia.org//meta.wikimedia.org/wiki/List_of_Wikipedias',
#  'http://wikipedia.org//de.wikipedia.org/wiki/Wikipedia:Sprachen',
#  'http://wikipedia.org//meta.wikimedia.org/wiki/Lista_de_Wikipedias',
#  'http://wikipedia.org//eo.wikipedia.org/wiki/Vikipedio:Internacia_Vikipedio',
#  'http://wikipedia.org//wikimediafoundation.org/',
#  'http://wikipedia.org//itunes.apple.com/app/apple-store/id324715238?pt=208305&ct=portal&mt=8',
#  'http://wikipedia.org//commons.wikimedia.org/',
#  'http://wikipedia.org//www.wikivoyage.org/',
#  'http://wikipedia.org//www.wiktionary.org/',
#  'http://wikipedia.org//www.wikibooks.org/',
#  'http://wikipedia.org//www.wikinews.org/',
#  'http://wikipedia.org//www.wikidata.org/',
#  'http://wikipedia.org//www.wikiversity.org/',
#  'http://wikipedia.org//www.wikiquote.org/',
#  'http://wikipedia.org//www.mediawiki.org/',
#  'http://wikipedia.org//www.wikisource.org/',
#  'http://wikipedia.org//species.wikimedia.org/',
#  'http://wikipedia.org//meta.wikimedia.org/',
#  'http://wikipedia.org//meta.wikimedia.org/wiki/Terms_of_Use',
#  'http://wikipedia.org//meta.wikimedia.org/wiki/Privacy_policy']

# %% [markdown]
# ## Step 4: Use the os library to create a folder called *wikipedia* and make that the current working directory.

# %%
import os

# %%
current_directory = os.getcwd()
final_directory = os.path.join(current_directory, r'wikipedia')
if not os.path.exists(final_directory):
   os.makedirs(final_directory)
print(final_directory)
# Out:
# /Users/anielkaaslan/Documents/GitHub/files/module-1/lab-parallelization/your-code/wikipedia

# %% [markdown]
# ## Step 5: Write a function called index_page that accepts a link and does the following.
#
# - Tries to request the content of the page referenced by that link.
# - Slugifies the filename using the `slugify` function from the [python-slugify](https://pypi.org/project/python-slugify/) library and adds a .html file extension.
#     - If you don't already have the python-slugify library installed, you can pip install it as follows: `$ pip install python-slugify`.
#     - To import the slugify function, you would do the following: `from slugify import slugify`.
#     - You can then slugify a link as follows `slugify(link)`.
# - Creates a file in the wikipedia folder using the slugified filename and writes the contents of the page to the file.
# - If an exception occurs during the process above, just `pass`.

# %%
from slugify import slugify

# %%
def index_page(url):
    try:
        html = requests.get(url).content
        soup = BeautifulSoup(html, "html.parser")
        title = soup.find('title').text
        slugify_title = slugify(title)
        filename = slugify_title + '.html'
        path = final_directory
        with open(os.path.join(path, filename), 'w', encoding='utf-8') as temp_file:
            temp_file.write(str(soup))
    except:
       pass

# %% [markdown]
# ## Step 6: Sequentially loop through the list of links, running the index_page function each time.
#
# Remember to include `%%time` at the beginning of the cell so that it measures the time it takes for the cell to run.

# %%
# %%time
for link in combine_links:
    index_page(link)
# Out:
# CPU times: user 21.7 s, sys: 1.86 s, total: 23.6 s
# Wall time: 6min 17s

# %% [markdown]
# ## Step 7: Perform the page indexing in parallel and note the difference in performance.
#
# Remember to include `%%time` at the beginning of the cell so that it measures the time it takes for the cell to run.

# %%
import multiprocessing

# %%
# %%time
pool = multiprocessing.Pool()
pool.map(index_page, combine_links)
pool.terminate()
pool.join()
# Out:
# CPU times: user 77.9 ms, sys: 46.7 ms, total: 125 ms
# Wall time: 1min 27s
# ERROR:root:Invalid alias: The name clear can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name more can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name less can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name man can't be aliased because it is another magic command.
