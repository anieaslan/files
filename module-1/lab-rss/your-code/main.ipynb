# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
rss = feedparser.parse(url)

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
rss.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
rss.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'updated', 'updated_parsed', 'language', 'sy_updateperiod', 'sy_updatefrequency', 'generator_detail', 'generator', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
print(rss.feed.title)
print(rss.feed.subtitle)
# feeds.feed.author (DOES NOT EXIST)
print(rss.feed.link)
# Out:
# Radar
# Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology
# https://www.oreilly.com/radar

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len(rss.entries)
# Out:
# 60

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
rss.entries[0].keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'comments', 'published', 'published_parsed', 'authors', 'author', 'author_detail', 'tags', 'id', 'guidislink', 'summary', 'summary_detail', 'content', 'wfw_commentrss', 'slash_comments', 'feedburner_origlink'])

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
# list_of_titles = (rss.feed.title)
# list_of_titles

titles = [rss.entries[i].title for i in range(len(rss.entries))]
print(titles)
# feeds.entries[].title
# Out:
# ['The unreasonable importance of data preparation', 'Four short links: 24 March 2020', '3 ways to confront modern business challenges', 'An enterprise vision is your company’s North Star', 'Leaders need to mobilize change-ready workforces', 'Great leaders inspire innovation and creativity from within their workforces', 'Strong leaders forge an intersection of knowledge and experience', 'Four short links: 23 March 2020', 'Four short links: 20 March 2020', '6 trends framing the state of AI and ML', 'Four short links: 19 March 2020', 'It’s an unprecedented crisis: 8 things to do right now', 'AI adoption in the enterprise 2020', 'Four short links: 18 March 2020', 'Four short links: 17 March 2020', 'Four short links: 16 March 2020', 'Four short links: 13 March 2020', 'Four short links: 12 March 2020', 'Four short links: 11 March 2020', 'Four short links: 10 March 2020', 'Four short links: 9 March 2020', 'Four short links: 6 March 2020', 'Radar trends to watch: March 2020', 'Four short links: 5 March 2020', 'Remembering Freeman Dyson', 'Four short links: 4 March 2020', 'Four short links: 3 March 2020', 'The death of Agile?', 'Four short links: 2 March 2020', 'Four short links: 28 February 2020', 'Four short links: 27 February 2020', 'Intellectual control', 'Highlights from the O’Reilly Software Architecture Conference in New York 2020', 'Where do great architectures come from?', 'Architecture.Next: Invalidating old axioms', 'Four short links: 26 February 2020', 'From the trenches: Rachel Laycock', 'Sometimes I draw', 'The elephant in the architecture', 'Four short links: 25 February 2020', 'Four short links: 24 February 2020', 'Four short links: 22 February 2020', 'Four short links: 20 February 2020', '10 ways to get untapped talent in your organization to contribute', 'Four short links: 19 February 2020', '5 key areas for tech leaders to watch in 2020', 'Four short links: 18 February 2020', 'Four short links: 17 February 2020', 'Four short links: 14 February 2020', 'Four short links: 13 February 2020', 'The state of data quality in 2020', 'Four short links: 12 February 2020', 'Four short links: 11 February 2020', 'Four short links: 10 February 2020', 'Four short links: 7 February 2020', 'Radar trends to watch: February 2020', 'Four short links: 6 February 2020', 'Four short links: 5 February 2020', 'Four short links: 4 February 2020', 'Four short links: 3 February 2020']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
count = 0
for x in titles:
    if 'Four short links' in x:
        count += 1

print(count/len(titles)*100)
# Out:
# 61.66666666666667

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
df = pd.DataFrame(rss.entries)
df
# Out:
#                              author  \
# 0               Hugo Bowne-Anderson
# 1                    Nat Torkington
# 2                      Rita J. King
# 3                         Jenn Webb
# 4                         Jenn Webb
# 5                         Jenn Webb
# 6                         Jenn Webb
# 7                    Nat Torkington
# 8                    Nat Torkington
# 9   Roger Magoulas and Steve Swoyer
# 10                   Nat Torkington
# 11                    Cynthia Owens
# 12  Roger Magoulas and Steve Swoyer
# 13                   Nat Torkington
# 14                   Nat Torkington
# 15                   Nat Torkington
# 16                   Nat Torkington
# 17                   Nat Torkington
# 18                   Nat Torkington
# 19                   Nat Torkington
# 20                   Nat Torkington
# 21                   Nat Torkington
# 22                    Mike Loukides
# 23                   Nat Torkington
# 24                     Tim O’Reilly
# 25                   Nat Torkington
# 26                   Nat Torkington
# 27                    Mike Loukides
# 28                   Nat Torkington
# 29                   Nat Torkington
# 30                   Nat Torkington
# 31                 George Fairbanks
# 32                       Mac Slocum
# 33                 Mary Poppendieck
# 34                    Mark Richards
# 35                   Nat Torkington
# 36     Rachel Laycock and Neal Ford
# 37                       Kai Holnes
# 38                    Martin Fowler
# 39                   Nat Torkington
# 40                   Nat Torkington
# 41                   Nat Torkington
# 42                   Nat Torkington
# 43                    Pamela Rucker
# 44                   Nat Torkington
# 45  Roger Magoulas and Steve Swoyer
# 46                   Nat Torkington
# 47                   Nat Torkington
# 48                   Nat Torkington
# 49                   Nat Torkington
# 50  Roger Magoulas and Steve Swoyer
# 51                   Nat Torkington
# 52                   Nat Torkington
# 53                   Nat Torkington
# 54                   Nat Torkington
# 55                    Mike Loukides
# 56                   Nat Torkington
# 57                   Nat Torkington
# 58                   Nat Torkington
# 59                   Nat Torkington
#
#                                   author_detail  \
# 0               {'name': 'Hugo Bowne-Anderson'}
# 1                    {'name': 'Nat Torkington'}
# 2                      {'name': 'Rita J. King'}
# 3                         {'name': 'Jenn Webb'}
# 4                         {'name': 'Jenn Webb'}
# 5                         {'name': 'Jenn Webb'}
# 6                         {'name': 'Jenn Webb'}
# 7                    {'name': 'Nat Torkington'}
# 8                    {'name': 'Nat Torkington'}
# 9   {'name': 'Roger Magoulas and Steve Swoyer'}
# 10                   {'name': 'Nat Torkington'}
# 11                    {'name': 'Cynthia Owens'}
# 12  {'name': 'Roger Magoulas and Steve Swoyer'}
# 13                   {'name': 'Nat Torkington'}
# 14                   {'name': 'Nat Torkington'}
# 15                   {'name': 'Nat Torkington'}
# 16                   {'name': 'Nat Torkington'}
# 17                   {'name': 'Nat Torkington'}
# 18                   {'name': 'Nat Torkington'}
# 19                   {'name': 'Nat Torkington'}
# 20                   {'name': 'Nat Torkington'}
# 21                   {'name': 'Nat Torkington'}
# 22                    {'name': 'Mike Loukides'}
# 23                   {'name': 'Nat Torkington'}
# 24                     {'name': 'Tim O’Reilly'}
# 25                   {'name': 'Nat Torkington'}
# 26                   {'name': 'Nat Torkington'}
# 27                    {'name': 'Mike Loukides'}
# 28                   {'name': 'Nat Torkington'}
# 29                   {'name': 'Nat Torkington'}
# 30                   {'name': 'Nat Torkington'}
# 31                 {'name': 'George Fairbanks'}
# 32                       {'name': 'Mac Slocum'}
# 33                 {'name': 'Mary Poppendieck'}
# 34                    {'name': 'Mark Richards'}
# 35                   {'name': 'Nat Torkington'}
# 36     {'name': 'Rachel Laycock and Neal Ford'}
# 37                       {'name': 'Kai Holnes'}
# 38                    {'name': 'Martin Fowler'}
# 39                   {'name': 'Nat Torkington'}
# 40                   {'name': 'Nat Torkington'}
# 41                   {'name': 'Nat Torkington'}
# 42                   {'name': 'Nat Torkington'}
# 43                    {'name': 'Pamela Rucker'}
# 44                   {'name': 'Nat Torkington'}
# 45  {'name': 'Roger Magoulas and Steve Swoyer'}
# 46                   {'name': 'Nat Torkington'}
# 47                   {'name': 'Nat Torkington'}
# 48                   {'name': 'Nat Torkington'}
# 49                   {'name': 'Nat Torkington'}
# 50  {'name': 'Roger Magoulas and Steve Swoyer'}
# 51                   {'name': 'Nat Torkington'}
# 52                   {'name': 'Nat Torkington'}
# 53                   {'name': 'Nat Torkington'}
# 54                   {'name': 'Nat Torkington'}
# 55                    {'name': 'Mike Loukides'}
# 56                   {'name': 'Nat Torkington'}
# 57                   {'name': 'Nat Torkington'}
# 58                   {'name': 'Nat Torkington'}
# 59                   {'name': 'Nat Torkington'}
#
#                                           authors  \
# 0               [{'name': 'Hugo Bowne-Anderson'}]
# 1                    [{'name': 'Nat Torkington'}]
# 2                      [{'name': 'Rita J. King'}]
# 3                         [{'name': 'Jenn Webb'}]
# 4                         [{'name': 'Jenn Webb'}]
# 5                         [{'name': 'Jenn Webb'}]
# 6                         [{'name': 'Jenn Webb'}]
# 7                    [{'name': 'Nat Torkington'}]
# 8                    [{'name': 'Nat Torkington'}]
# 9   [{'name': 'Roger Magoulas and Steve Swoyer'}]
# 10                   [{'name': 'Nat Torkington'}]
# 11                    [{'name': 'Cynthia Owens'}]
# 12  [{'name': 'Roger Magoulas and Steve Swoyer'}]
# 13                   [{'name': 'Nat Torkington'}]
# 14                   [{'name': 'Nat Torkington'}]
# 15                   [{'name': 'Nat Torkington'}]
# 16                   [{'name': 'Nat Torkington'}]
# 17                   [{'name': 'Nat Torkington'}]
# 18                   [{'name': 'Nat Torkington'}]
# 19                   [{'name': 'Nat Torkington'}]
# 20                   [{'name': 'Nat Torkington'}]
# 21                   [{'name': 'Nat Torkington'}]
# 22                    [{'name': 'Mike Loukides'}]
# 23                   [{'name': 'Nat Torkington'}]
# 24                     [{'name': 'Tim O’Reilly'}]
# 25                   [{'name': 'Nat Torkington'}]
# 26                   [{'name': 'Nat Torkington'}]
# 27                    [{'name': 'Mike Loukides'}]
# 28                   [{'name': 'Nat Torkington'}]
# 29                   [{'name': 'Nat Torkington'}]
# 30                   [{'name': 'Nat Torkington'}]
# 31                 [{'name': 'George Fairbanks'}]
# 32                       [{'name': 'Mac Slocum'}]
# 33                 [{'name': 'Mary Poppendieck'}]
# 34                    [{'name': 'Mark Richards'}]
# 35                   [{'name': 'Nat Torkington'}]
# 36     [{'name': 'Rachel Laycock and Neal Ford'}]
# 37                       [{'name': 'Kai Holnes'}]
# 38                    [{'name': 'Martin Fowler'}]
# 39                   [{'name': 'Nat Torkington'}]
# 40                   [{'name': 'Nat Torkington'}]
# 41                   [{'name': 'Nat Torkington'}]
# 42                   [{'name': 'Nat Torkington'}]
# 43                    [{'name': 'Pamela Rucker'}]
# 44                   [{'name': 'Nat Torkington'}]
# 45  [{'name': 'Roger Magoulas and Steve Swoyer'}]
# 46                   [{'name': 'Nat Torkington'}]
# 47                   [{'name': 'Nat Torkington'}]
# 48                   [{'name': 'Nat Torkington'}]
# 49                   [{'name': 'Nat Torkington'}]
# 50  [{'name': 'Roger Magoulas and Steve Swoyer'}]
# 51                   [{'name': 'Nat Torkington'}]
# 52                   [{'name': 'Nat Torkington'}]
# 53                   [{'name': 'Nat Torkington'}]
# 54                   [{'name': 'Nat Torkington'}]
# 55                    [{'name': 'Mike Loukides'}]
# 56                   [{'name': 'Nat Torkington'}]
# 57                   [{'name': 'Nat Torkington'}]
# 58                   [{'name': 'Nat Torkington'}]
# 59                   [{'name': 'Nat Torkington'}]
#
#                                              comments  \
# 0   https://www.oreilly.com/radar/the-unreasonable...
# 1   https://www.oreilly.com/radar/four-short-links...
# 2   https://www.oreilly.com/radar/3-ways-to-confro...
# 3   https://www.oreilly.com/radar/an-enterprise-vi...
# 4   https://www.oreilly.com/radar/leaders-need-to-...
# 5   https://www.oreilly.com/radar/great-leaders-in...
# 6   https://www.oreilly.com/radar/strong-leaders-f...
# 7   https://www.oreilly.com/radar/four-short-links...
# 8   https://www.oreilly.com/radar/four-short-links...
# 9   https://www.oreilly.com/radar/6-trends-framing...
# 10  https://www.oreilly.com/radar/four-short-links...
# 11  https://www.oreilly.com/radar/its-an-unprecede...
# 12  https://www.oreilly.com/radar/ai-adoption-in-t...
# 13  https://www.oreilly.com/radar/four-short-links...
# 14  https://www.oreilly.com/radar/four-short-links...
# 15  https://www.oreilly.com/radar/four-short-links...
# 16  https://www.oreilly.com/radar/four-short-links...
# 17  https://www.oreilly.com/radar/four-short-links...
# 18  https://www.oreilly.com/radar/four-short-links...
# 19  https://www.oreilly.com/radar/four-short-links...
# 20  https://www.oreilly.com/radar/four-short-links...
# 21  https://www.oreilly.com/radar/four-short-links...
# 22  https://www.oreilly.com/radar/radar-trends-to-...
# 23  https://www.oreilly.com/radar/four-short-links...
# 24  https://www.oreilly.com/radar/remembering-free...
# 25  https://www.oreilly.com/radar/four-short-links...
# 26  https://www.oreilly.com/radar/four-short-links...
# 27  https://www.oreilly.com/radar/the-death-of-agi...
# 28  https://www.oreilly.com/radar/four-short-links...
# 29  https://www.oreilly.com/radar/four-short-links...
# 30  https://www.oreilly.com/radar/four-short-links...
# 31  https://www.oreilly.com/radar/intellectual-con...
# 32  https://www.oreilly.com/radar/highlights-from-...
# 33  https://www.oreilly.com/radar/where-do-great-a...
# 34  https://www.oreilly.com/radar/architecture-nex...
# 35  https://www.oreilly.com/radar/four-short-links...
# 36  https://www.oreilly.com/radar/from-the-trenche...
# 37  https://www.oreilly.com/radar/sometimes-i-draw...
# 38  https://www.oreilly.com/radar/the-elephant-in-...
# 39  https://www.oreilly.com/radar/four-short-links...
# 40  https://www.oreilly.com/radar/four-short-links...
# 41  https://www.oreilly.com/radar/four-short-links...
# 42  https://www.oreilly.com/radar/four-short-links...
# 43  https://www.oreilly.com/radar/10-ways-to-get-u...
# 44  https://www.oreilly.com/radar/four-short-links...
# 45  https://www.oreilly.com/radar/oreilly-2020-pla...
# 46  https://www.oreilly.com/radar/four-short-links...
# 47  https://www.oreilly.com/radar/four-short-links...
# 48  https://www.oreilly.com/radar/four-short-links...
# 49  https://www.oreilly.com/radar/four-short-links...
# 50  https://www.oreilly.com/radar/the-state-of-dat...
# 51  https://www.oreilly.com/radar/four-short-links...
# 52  https://www.oreilly.com/radar/four-short-links...
# 53  https://www.oreilly.com/radar/four-short-links...
# 54  https://www.oreilly.com/radar/four-short-links...
# 55  https://www.oreilly.com/radar/radar-trends-to-...
# 56  https://www.oreilly.com/radar/four-short-links...
# 57  https://www.oreilly.com/radar/four-short-links...
# 58  https://www.oreilly.com/radar/four-short-links...
# 59  https://www.oreilly.com/radar/four-short-links...
#
#                                               content  \
# 0   [{'type': 'text/html', 'language': None, 'base...
# 1   [{'type': 'text/html', 'language': None, 'base...
# 2   [{'type': 'text/html', 'language': None, 'base...
# 3   [{'type': 'text/html', 'language': None, 'base...
# 4   [{'type': 'text/html', 'language': None, 'base...
# 5   [{'type': 'text/html', 'language': None, 'base...
# 6   [{'type': 'text/html', 'language': None, 'base...
# 7   [{'type': 'text/html', 'language': None, 'base...
# 8   [{'type': 'text/html', 'language': None, 'base...
# 9   [{'type': 'text/html', 'language': None, 'base...
# 10  [{'type': 'text/html', 'language': None, 'base...
# 11  [{'type': 'text/html', 'language': None, 'base...
# 12  [{'type': 'text/html', 'language': None, 'base...
# 13  [{'type': 'text/html', 'language': None, 'base...
# 14  [{'type': 'text/html', 'language': None, 'base...
# 15  [{'type': 'text/html', 'language': None, 'base...
# 16  [{'type': 'text/html', 'language': None, 'base...
# 17  [{'type': 'text/html', 'language': None, 'base...
# 18  [{'type': 'text/html', 'language': None, 'base...
# 19  [{'type': 'text/html', 'language': None, 'base...
# 20  [{'type': 'text/html', 'language': None, 'base...
# 21  [{'type': 'text/html', 'language': None, 'base...
# 22  [{'type': 'text/html', 'language': None, 'base...
# 23  [{'type': 'text/html', 'language': None, 'base...
# 24  [{'type': 'text/html', 'language': None, 'base...
# 25  [{'type': 'text/html', 'language': None, 'base...
# 26  [{'type': 'text/html', 'language': None, 'base...
# 27  [{'type': 'text/html', 'language': None, 'base...
# 28  [{'type': 'text/html', 'language': None, 'base...
# 29  [{'type': 'text/html', 'language': None, 'base...
# 30  [{'type': 'text/html', 'language': None, 'base...
# 31  [{'type': 'text/html', 'language': None, 'base...
# 32  [{'type': 'text/html', 'language': None, 'base...
# 33  [{'type': 'text/html', 'language': None, 'base...
# 34  [{'type': 'text/html', 'language': None, 'base...
# 35  [{'type': 'text/html', 'language': None, 'base...
# 36  [{'type': 'text/html', 'language': None, 'base...
# 37  [{'type': 'text/html', 'language': None, 'base...
# 38  [{'type': 'text/html', 'language': None, 'base...
# 39  [{'type': 'text/html', 'language': None, 'base...
# 40  [{'type': 'text/html', 'language': None, 'base...
# 41  [{'type': 'text/html', 'language': None, 'base...
# 42  [{'type': 'text/html', 'language': None, 'base...
# 43  [{'type': 'text/html', 'language': None, 'base...
# 44  [{'type': 'text/html', 'language': None, 'base...
# 45  [{'type': 'text/html', 'language': None, 'base...
# 46  [{'type': 'text/html', 'language': None, 'base...
# 47  [{'type': 'text/html', 'language': None, 'base...
# 48  [{'type': 'text/html', 'language': None, 'base...
# 49  [{'type': 'text/html', 'language': None, 'base...
# 50  [{'type': 'text/html', 'language': None, 'base...
# 51  [{'type': 'text/html', 'language': None, 'base...
# 52  [{'type': 'text/html', 'language': None, 'base...
# 53  [{'type': 'text/html', 'language': None, 'base...
# 54  [{'type': 'text/html', 'language': None, 'base...
# 55  [{'type': 'text/html', 'language': None, 'base...
# 56  [{'type': 'text/html', 'language': None, 'base...
# 57  [{'type': 'text/html', 'language': None, 'base...
# 58  [{'type': 'text/html', 'language': None, 'base...
# 59  [{'type': 'text/html', 'language': None, 'base...
#
#                                   feedburner_origlink  guidislink  \
# 0   https://www.oreilly.com/radar/the-unreasonable...       False
# 1   https://www.oreilly.com/radar/four-short-links...       False
# 2   https://www.oreilly.com/radar/3-ways-to-confro...       False
# 3   https://www.oreilly.com/radar/an-enterprise-vi...       False
# 4   https://www.oreilly.com/radar/leaders-need-to-...       False
# 5   https://www.oreilly.com/radar/great-leaders-in...       False
# 6   https://www.oreilly.com/radar/strong-leaders-f...       False
# 7   https://www.oreilly.com/radar/four-short-links...       False
# 8   https://www.oreilly.com/radar/four-short-links...       False
# 9   https://www.oreilly.com/radar/6-trends-framing...       False
# 10  https://www.oreilly.com/radar/four-short-links...       False
# 11  https://www.oreilly.com/radar/its-an-unprecede...       False
# 12  https://www.oreilly.com/radar/ai-adoption-in-t...       False
# 13  https://www.oreilly.com/radar/four-short-links...       False
# 14  https://www.oreilly.com/radar/four-short-links...       False
# 15  https://www.oreilly.com/radar/four-short-links...       False
# 16  https://www.oreilly.com/radar/four-short-links...       False
# 17  https://www.oreilly.com/radar/four-short-links...       False
# 18  https://www.oreilly.com/radar/four-short-links...       False
# 19  https://www.oreilly.com/radar/four-short-links...       False
# 20  https://www.oreilly.com/radar/four-short-links...       False
# 21  https://www.oreilly.com/radar/four-short-links...       False
# 22  https://www.oreilly.com/radar/radar-trends-to-...       False
# 23  https://www.oreilly.com/radar/four-short-links...       False
# 24  https://www.oreilly.com/radar/remembering-free...       False
# 25  https://www.oreilly.com/radar/four-short-links...       False
# 26  https://www.oreilly.com/radar/four-short-links...       False
# 27  https://www.oreilly.com/radar/the-death-of-agile/       False
# 28  https://www.oreilly.com/radar/four-short-links...       False
# 29  https://www.oreilly.com/radar/four-short-links...       False
# 30  https://www.oreilly.com/radar/four-short-links...       False
# 31  https://www.oreilly.com/radar/intellectual-con...       False
# 32  https://www.oreilly.com/radar/highlights-from-...       False
# 33  https://www.oreilly.com/radar/where-do-great-a...       False
# 34  https://www.oreilly.com/radar/architecture-nex...       False
# 44  Wed, 19 Feb 2020 05:01:00 +0000    (2020, 2, 19, 5, 1, 0, 2, 50, 0)
# 45  Tue, 18 Feb 2020 11:00:00 +0000   (2020, 2, 18, 11, 0, 0, 1, 49, 0)
# 46  Tue, 18 Feb 2020 05:01:00 +0000    (2020, 2, 18, 5, 1, 0, 1, 49, 0)
# 47  Mon, 17 Feb 2020 05:01:00 +0000    (2020, 2, 17, 5, 1, 0, 0, 48, 0)
# 48  Fri, 14 Feb 2020 05:01:00 +0000    (2020, 2, 14, 5, 1, 0, 4, 45, 0)
# 49  Thu, 13 Feb 2020 05:01:00 +0000    (2020, 2, 13, 5, 1, 0, 3, 44, 0)
# 50  Wed, 12 Feb 2020 06:00:00 +0000    (2020, 2, 12, 6, 0, 0, 2, 43, 0)
# 51  Wed, 12 Feb 2020 05:01:00 +0000    (2020, 2, 12, 5, 1, 0, 2, 43, 0)
# 52  Tue, 11 Feb 2020 05:01:00 +0000    (2020, 2, 11, 5, 1, 0, 1, 42, 0)
# 53  Mon, 10 Feb 2020 05:01:00 +0000    (2020, 2, 10, 5, 1, 0, 0, 41, 0)
# 54  Fri, 07 Feb 2020 05:01:00 +0000     (2020, 2, 7, 5, 1, 0, 4, 38, 0)
# 55  Thu, 06 Feb 2020 11:00:00 +0000    (2020, 2, 6, 11, 0, 0, 3, 37, 0)
# 56  Thu, 06 Feb 2020 05:01:00 +0000     (2020, 2, 6, 5, 1, 0, 3, 37, 0)
# 57  Wed, 05 Feb 2020 05:01:00 +0000     (2020, 2, 5, 5, 1, 0, 2, 36, 0)
# 58  Tue, 04 Feb 2020 05:01:00 +0000     (2020, 2, 4, 5, 1, 0, 1, 35, 0)
# 59  Mon, 03 Feb 2020 05:01:00 +0000     (2020, 2, 3, 5, 1, 0, 0, 34, 0)
#
#    slash_comments                                            summary  \
# 0               0  In a world focused on buzzword-driven models a...
# 1               0  Potential Distributed Reading Group on Distrib...
# 2               0  I interviewed four business leaders in late 20...
# 3               0  Rita J. King, co-director and EVP for business...
# 4               0  Rita J. King, co-director and EVP for business...
# 5               0  Rita J. King, co-director and EVP for business...
# 6               0  Rita J. King, co-director and EVP for business...
# 7               0  Stanza: A Python Natural Language Processing T...
# 8               0  NASCAR Replaces Canceled Races with Esports Fe...
# 9               0  O’Reilly online learning is a trove of informa...
# 10              0  Dos and Don&#8217;ts in Open Source (Olaf Geir...
# 11              0  Even with a stellar crisis plan, the COVID-19 ...
# 12              0  Last year, when we felt interest in artificial...
# 13              0  Inklewriter &#8212; open source interactive te...
# 14              0  How the Great Firewall Discovers Hidden Circum...
# 15              0  The Uncensored Library &#8212; Reporters Witho...
# 16              0  OpenAM &#8212; an open-access management solut...
# 17              0  AWS Bill Analysis &#8212; always interesting t...
# 18              0  Pluralistic &#8212; Cory Doctorow&#8217;s news...
# 19              0  MLflow &#8212; an open source platform to mana...
# 20              0  Sno &#8212; Distributed version control for ge...
# 21              0  Soul of a New Machine: Rethinking the Computer...
# 22              0  AI in practice In his book TinyML, Pete Warden...
# 23              0  libfacedetection &#8212; they claim 1000fps. O...
# 24              0  Freeman Dyson died last week at the age of 96 ...
# 25              0  tota11y &#8212; an [open source] accessibility...
# 26              0  Facebook&#8217;s Incomplete Download Your Data...
# 27              0  I read an article on the death of Agile. It&#8...
# 28              0  Gandalf: An Intelligent, End-to-end Analytics ...
# 29              0  Mapping Coronavirus Responsibly (ESRI) &#8212;...
# 30              0  BellTopo Sans &#8212; typeface and free font i...
# 31              0  This is a keynote highlight from the O&#8217;R...
# 32              0  People from across the software architecture w...
# 33              0  This is a keynote highlight from the O&#8217;R...
# 34              0  This is a keynote highlight from the O&#8217;R...
# 35              0  kernel-wasm &#8212; Safely run WebAssembly in ...
# 36              0  This is a keynote highlight from the O&#8217;R...
# 37              0  This is a keynote highlight from the O&#8217;R...
# 38              0  This is a keynote highlight from the O&#8217;R...
# 39              0  Dispatch &#8212; Netflix&#8217;s incident mana...
# 40              0  YOLO Creator Leaves Computer Vision &#8212; Jo...
# 41              0  Teachable Machine &#8212; Google&#8217;s codel...
# 42              0  Hacker Laws &#8212; a lot of classics, like Cu...
# 43              0  Every day, leaders actively look for ways to u...
# 44              0  Devil&#8217;s Dictionary of Programming &#8212...
# 45              0  O’Reilly online learning contains information ...
# 46              0  Millions of Tiny Databases &#8212; a distribut...
# 47              0  Coders are not Hackers: Hacker Culture is Dead...
# 48              0  ABD &#8212; Course materials for Advanced Bina...
# 49              0  Ofcom To Regulate UK Internet &#8212; The regu...
# 50              0  We suspected that data quality was a topic bri...
# 51              0  Drafting an Engineering Strategy (Mathias Meye...
# 52              0  The Fate of Empires &#8212; 1977 text summariz...
# 53              0  The Digital Dictators: How Technology Strength...
# 54              0  31 Days of API Security Tips &#8212; Mobile Ce...
# 55              0  Automation and infrastructure trends IBM has r...
# 56              0  Assembler &#8212; Google&#8217;s Jigsaw group ...
# 57              0  Discord Switching from Go to Rust &#8212; memo...
# 58              0  The Missing Semester of Your MIT Education &#8...
# 59              0  Standing on the Shoulders of Giants (Ben Evans...
#
#                                        summary_detail  \
# 0   {'type': 'text/html', 'language': None, 'base'...
# 1   {'type': 'text/html', 'language': None, 'base'...
# 2   {'type': 'text/html', 'language': None, 'base'...
# 3   {'type': 'text/html', 'language': None, 'base'...
# 4   {'type': 'text/html', 'language': None, 'base'...
# 5   {'type': 'text/html', 'language': None, 'base'...
# 6   {'type': 'text/html', 'language': None, 'base'...
# 7   {'type': 'text/html', 'language': None, 'base'...
# 8   {'type': 'text/html', 'language': None, 'base'...
# 9   {'type': 'text/html', 'language': None, 'base'...
# 10  {'type': 'text/html', 'language': None, 'base'...
# 11  {'type': 'text/html', 'language': None, 'base'...
# 12  {'type': 'text/html', 'language': None, 'base'...
# 13  {'type': 'text/html', 'language': None, 'base'...
# 14  {'type': 'text/html', 'language': None, 'base'...
# 15  {'type': 'text/html', 'language': None, 'base'...
# 16  {'type': 'text/html', 'language': None, 'base'...
# 17  {'type': 'text/html', 'language': None, 'base'...
# 18  {'type': 'text/html', 'language': None, 'base'...
# 19  {'type': 'text/html', 'language': None, 'base'...
# 20  {'type': 'text/html', 'language': None, 'base'...
# 21  {'type': 'text/html', 'language': None, 'base'...
# 22  {'type': 'text/html', 'language': None, 'base'...
# 23  {'type': 'text/html', 'language': None, 'base'...
# 24  {'type': 'text/html', 'language': None, 'base'...
# 25  {'type': 'text/html', 'language': None, 'base'...
# 26  {'type': 'text/html', 'language': None, 'base'...
# 27  {'type': 'text/html', 'language': None, 'base'...
# 28  {'type': 'text/html', 'language': None, 'base'...
# 29  {'type': 'text/html', 'language': None, 'base'...
# 30  {'type': 'text/html', 'language': None, 'base'...
# 31  {'type': 'text/html', 'language': None, 'base'...
# 32  {'type': 'text/html', 'language': None, 'base'...
# 33  {'type': 'text/html', 'language': None, 'base'...
# 34  {'type': 'text/html', 'language': None, 'base'...
# 35  {'type': 'text/html', 'language': None, 'base'...
# 36  {'type': 'text/html', 'language': None, 'base'...
# 37  {'type': 'text/html', 'language': None, 'base'...
# 38  {'type': 'text/html', 'language': None, 'base'...
# 39  {'type': 'text/html', 'language': None, 'base'...
# 40  {'type': 'text/html', 'language': None, 'base'...
# 41  {'type': 'text/html', 'language': None, 'base'...
# 42  {'type': 'text/html', 'language': None, 'base'...
# 43  {'type': 'text/html', 'language': None, 'base'...
# 44  {'type': 'text/html', 'language': None, 'base'...
# 45  {'type': 'text/html', 'language': None, 'base'...
# 46  {'type': 'text/html', 'language': None, 'base'...
# 47  {'type': 'text/html', 'language': None, 'base'...
# 48  {'type': 'text/html', 'language': None, 'base'...
# 49  {'type': 'text/html', 'language': None, 'base'...
# 50  {'type': 'text/html', 'language': None, 'base'...
# 51  {'type': 'text/html', 'language': None, 'base'...
# 52  {'type': 'text/html', 'language': None, 'base'...
# 53  {'type': 'text/html', 'language': None, 'base'...
# 54  {'type': 'text/html', 'language': None, 'base'...
# 55  {'type': 'text/html', 'language': None, 'base'...
# 56  {'type': 'text/html', 'language': None, 'base'...
# 57  {'type': 'text/html', 'language': None, 'base'...
# 58  {'type': 'text/html', 'language': None, 'base'...
# 59  {'type': 'text/html', 'language': None, 'base'...
#
#                                                  tags  \
# 0   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 1   [{'term': 'Four Short Links', 'scheme': None, ...
# 2   [{'term': 'Future of the Firm', 'scheme': None...
# 3   [{'term': 'Future of the Firm', 'scheme': None...
# 4   [{'term': 'Future of the Firm', 'scheme': None...
# 5   [{'term': 'Future of the Firm', 'scheme': None...
# 6   [{'term': 'Future of the Firm', 'scheme': None...
# 7   [{'term': 'Four Short Links', 'scheme': None, ...
# 8   [{'term': 'Four Short Links', 'scheme': None, ...
# 9   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 10  [{'term': 'Four Short Links', 'scheme': None, ...
# 11  [{'term': 'Future of the Firm', 'scheme': None...
# 12  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 13  [{'term': 'Four Short Links', 'scheme': None, ...
# 14  [{'term': 'Four Short Links', 'scheme': None, ...
# 15  [{'term': 'Four Short Links', 'scheme': None, ...
# 16  [{'term': 'Four Short Links', 'scheme': None, ...
# 17  [{'term': 'Four Short Links', 'scheme': None, ...
# 18  [{'term': 'Four Short Links', 'scheme': None, ...
# 19  [{'term': 'Four Short Links', 'scheme': None, ...
# 20  [{'term': 'Four Short Links', 'scheme': None, ...
# 21  [{'term': 'Four Short Links', 'scheme': None, ...
# 22  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 23  [{'term': 'Four Short Links', 'scheme': None, ...
# 24  [{'term': 'Innovation & Disruption', 'scheme':...
# 25  [{'term': 'Four Short Links', 'scheme': None, ...
# 26  [{'term': 'Four Short Links', 'scheme': None, ...
# 27  [{'term': 'Next Architecture', 'scheme': None,...
# 28  [{'term': 'Four Short Links', 'scheme': None, ...
# 29  [{'term': 'Four Short Links', 'scheme': None, ...
# 30  [{'term': 'Four Short Links', 'scheme': None, ...
# 31  [{'term': 'Next Architecture', 'scheme': None,...
# 32  [{'term': 'Next Architecture', 'scheme': None,...
# 33  [{'term': 'Next Architecture', 'scheme': None,...
# 34  [{'term': 'Next Architecture', 'scheme': None,...
# 35  [{'term': 'Four Short Links', 'scheme': None, ...
# 36  [{'term': 'Next Architecture', 'scheme': None,...
# 37  [{'term': 'Next Architecture', 'scheme': None,...
# 38  [{'term': 'Next Architecture', 'scheme': None,...
# 39  [{'term': 'Four Short Links', 'scheme': None, ...
# 40  [{'term': 'Four Short Links', 'scheme': None, ...
# 41  [{'term': 'Four Short Links', 'scheme': None, ...
# 42  [{'term': 'Four Short Links', 'scheme': None, ...
# 43  [{'term': 'Future of the Firm', 'scheme': None...
# 44  [{'term': 'Four Short Links', 'scheme': None, ...
# 45  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 46  [{'term': 'Four Short Links', 'scheme': None, ...
# 47  [{'term': 'Four Short Links', 'scheme': None, ...
# 48  [{'term': 'Four Short Links', 'scheme': None, ...
# 49  [{'term': 'Four Short Links', 'scheme': None, ...
# 50  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 51  [{'term': 'Four Short Links', 'scheme': None, ...
# 52  [{'term': 'Four Short Links', 'scheme': None, ...
# 53  [{'term': 'Four Short Links', 'scheme': None, ...
# 54  [{'term': 'Four Short Links', 'scheme': None, ...
# 55  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 56  [{'term': 'Four Short Links', 'scheme': None, ...
# 57  [{'term': 'Four Short Links', 'scheme': None, ...
# 58  [{'term': 'Four Short Links', 'scheme': None, ...
# 59  [{'term': 'Four Short Links', 'scheme': None, ...
#
#                                                 title  \
# 0     The unreasonable importance of data preparation
# 1                     Four short links: 24 March 2020
# 2       3 ways to confront modern business challenges
# 3   An enterprise vision is your company’s North Star
# 4    Leaders need to mobilize change-ready workforces
# 5   Great leaders inspire innovation and creativit...
# 6   Strong leaders forge an intersection of knowle...
# 7                     Four short links: 23 March 2020
# 8                     Four short links: 20 March 2020
# 9             6 trends framing the state of AI and ML
# 10                    Four short links: 19 March 2020
# 11  It’s an unprecedented crisis: 8 things to do r...
# 12                 AI adoption in the enterprise 2020
# 13                    Four short links: 18 March 2020
# 14                    Four short links: 17 March 2020
# 15                    Four short links: 16 March 2020
# 16                    Four short links: 13 March 2020
# 17                    Four short links: 12 March 2020
# 18                    Four short links: 11 March 2020
# 19                    Four short links: 10 March 2020
# 20                     Four short links: 9 March 2020
# 21                     Four short links: 6 March 2020
# 22                  Radar trends to watch: March 2020
# 23                     Four short links: 5 March 2020
# 24                          Remembering Freeman Dyson
# 25                     Four short links: 4 March 2020
# 26                     Four short links: 3 March 2020
# 27                                The death of Agile?
# 28                     Four short links: 2 March 2020
# 29                 Four short links: 28 February 2020
# 30                 Four short links: 27 February 2020
# 31                               Intellectual control
# 32  Highlights from the O’Reilly Software Architec...
# 33            Where do great architectures come from?
# 34         Architecture.Next: Invalidating old axioms
# 35                 Four short links: 26 February 2020
# 36                  From the trenches: Rachel Laycock
# 37                                   Sometimes I draw
# 38                   The elephant in the architecture
# 39                 Four short links: 25 February 2020
# 40                 Four short links: 24 February 2020
# 41                 Four short links: 22 February 2020
# 42                 Four short links: 20 February 2020
# 43  10 ways to get untapped talent in your organiz...
# 44                 Four short links: 19 February 2020
# 45      5 key areas for tech leaders to watch in 2020
# 46                 Four short links: 18 February 2020
# 47                 Four short links: 17 February 2020
# 48                 Four short links: 14 February 2020
# 49                 Four short links: 13 February 2020
# 50                  The state of data quality in 2020
# 51                 Four short links: 12 February 2020
# 52                 Four short links: 11 February 2020
# 53                 Four short links: 10 February 2020
# 54                  Four short links: 7 February 2020
# 55               Radar trends to watch: February 2020
# 56                  Four short links: 6 February 2020
# 57                  Four short links: 5 February 2020
# 58                  Four short links: 4 February 2020
# 59                  Four short links: 3 February 2020
#
#                                          title_detail  \
# 0   {'type': 'text/plain', 'language': None, 'base...
# 1   {'type': 'text/plain', 'language': None, 'base...
# 2   {'type': 'text/plain', 'language': None, 'base...
# 3   {'type': 'text/plain', 'language': None, 'base...
# 4   {'type': 'text/plain', 'language': None, 'base...
# 5   {'type': 'text/plain', 'language': None, 'base...
# 6   {'type': 'text/plain', 'language': None, 'base...
# 7   {'type': 'text/plain', 'language': None, 'base...
# 8   {'type': 'text/plain', 'language': None, 'base...
# 9   {'type': 'text/plain', 'language': None, 'base...
# 10  {'type': 'text/plain', 'language': None, 'base...
# 11  {'type': 'text/plain', 'language': None, 'base...
# 12  {'type': 'text/plain', 'language': None, 'base...
# 13  {'type': 'text/plain', 'language': None, 'base...
# 14  {'type': 'text/plain', 'language': None, 'base...
# 15  {'type': 'text/plain', 'language': None, 'base...
# 16  {'type': 'text/plain', 'language': None, 'base...
# 17  {'type': 'text/plain', 'language': None, 'base...
# 18  {'type': 'text/plain', 'language': None, 'base...
# 19  {'type': 'text/plain', 'language': None, 'base...
# 20  {'type': 'text/plain', 'language': None, 'base...
# 21  {'type': 'text/plain', 'language': None, 'base...
# 22  {'type': 'text/plain', 'language': None, 'base...
# 23  {'type': 'text/plain', 'language': None, 'base...
# 24  {'type': 'text/plain', 'language': None, 'base...
# 25  {'type': 'text/plain', 'language': None, 'base...
# 26  {'type': 'text/plain', 'language': None, 'base...
# 27  {'type': 'text/plain', 'language': None, 'base...
# 28  {'type': 'text/plain', 'language': None, 'base...
# 29  {'type': 'text/plain', 'language': None, 'base...
# 30  {'type': 'text/plain', 'language': None, 'base...
# 31  {'type': 'text/plain', 'language': None, 'base...
# 32  {'type': 'text/plain', 'language': None, 'base...
# 33  {'type': 'text/plain', 'language': None, 'base...
# 34  {'type': 'text/plain', 'language': None, 'base...
# 35  {'type': 'text/plain', 'language': None, 'base...
# 36  {'type': 'text/plain', 'language': None, 'base...
# 37  {'type': 'text/plain', 'language': None, 'base...
# 38  {'type': 'text/plain', 'language': None, 'base...
# 39  {'type': 'text/plain', 'language': None, 'base...
# 40  {'type': 'text/plain', 'language': None, 'base...
# 41  {'type': 'text/plain', 'language': None, 'base...
# 42  {'type': 'text/plain', 'language': None, 'base...
# 43  {'type': 'text/plain', 'language': None, 'base...
# 44  {'type': 'text/plain', 'language': None, 'base...
# 45  {'type': 'text/plain', 'language': None, 'base...
# 46  {'type': 'text/plain', 'language': None, 'base...
# 47  {'type': 'text/plain', 'language': None, 'base...
# 48  {'type': 'text/plain', 'language': None, 'base...
# 49  {'type': 'text/plain', 'language': None, 'base...
# 50  {'type': 'text/plain', 'language': None, 'base...
# 51  {'type': 'text/plain', 'language': None, 'base...
# 52  {'type': 'text/plain', 'language': None, 'base...
# 53  {'type': 'text/plain', 'language': None, 'base...
# 54  {'type': 'text/plain', 'language': None, 'base...
# 55  {'type': 'text/plain', 'language': None, 'base...
# 56  {'type': 'text/plain', 'language': None, 'base...
# 57  {'type': 'text/plain', 'language': None, 'base...
# 58  {'type': 'text/plain', 'language': None, 'base...
# 59  {'type': 'text/plain', 'language': None, 'base...
#
#                                        wfw_commentrss
# 0   https://www.oreilly.com/radar/the-unreasonable...
# 1   https://www.oreilly.com/radar/four-short-links...
# 2   https://www.oreilly.com/radar/3-ways-to-confro...
# 3   https://www.oreilly.com/radar/an-enterprise-vi...
# 4   https://www.oreilly.com/radar/leaders-need-to-...
# 5   https://www.oreilly.com/radar/great-leaders-in...
# 6   https://www.oreilly.com/radar/strong-leaders-f...
# 7   https://www.oreilly.com/radar/four-short-links...
# 8   https://www.oreilly.com/radar/four-short-links...
# 9   https://www.oreilly.com/radar/6-trends-framing...
# 10  https://www.oreilly.com/radar/four-short-links...
# 11  https://www.oreilly.com/radar/its-an-unprecede...
# 12  https://www.oreilly.com/radar/ai-adoption-in-t...
# 13  https://www.oreilly.com/radar/four-short-links...
# 14  https://www.oreilly.com/radar/four-short-links...
# 15  https://www.oreilly.com/radar/four-short-links...
# 16  https://www.oreilly.com/radar/four-short-links...
# 17  https://www.oreilly.com/radar/four-short-links...
# 18  https://www.oreilly.com/radar/four-short-links...
# 19  https://www.oreilly.com/radar/four-short-links...
# 20  https://www.oreilly.com/radar/four-short-links...
# 21  https://www.oreilly.com/radar/four-short-links...
# 22  https://www.oreilly.com/radar/radar-trends-to-...
# 23  https://www.oreilly.com/radar/four-short-links...
# 24  https://www.oreilly.com/radar/remembering-free...
# 25  https://www.oreilly.com/radar/four-short-links...
# 26  https://www.oreilly.com/radar/four-short-links...
# 27  https://www.oreilly.com/radar/the-death-of-agi...
# 28  https://www.oreilly.com/radar/four-short-links...
# 29  https://www.oreilly.com/radar/four-short-links...
# 30  https://www.oreilly.com/radar/four-short-links...
# 31  https://www.oreilly.com/radar/intellectual-con...
# 32  https://www.oreilly.com/radar/highlights-from-...
# 33  https://www.oreilly.com/radar/where-do-great-a...
# 34  https://www.oreilly.com/radar/architecture-nex...
# 35  https://www.oreilly.com/radar/four-short-links...
# 36  https://www.oreilly.com/radar/from-the-trenche...
# 37  https://www.oreilly.com/radar/sometimes-i-draw...
# 38  https://www.oreilly.com/radar/the-elephant-in-...
# 39  https://www.oreilly.com/radar/four-short-links...
# 40  https://www.oreilly.com/radar/four-short-links...
# 41  https://www.oreilly.com/radar/four-short-links...
# 42  https://www.oreilly.com/radar/four-short-links...
# 43  https://www.oreilly.com/radar/10-ways-to-get-u...
# 44  https://www.oreilly.com/radar/four-short-links...
# 45  https://www.oreilly.com/radar/oreilly-2020-pla...
# 46  https://www.oreilly.com/radar/four-short-links...
# 47  https://www.oreilly.com/radar/four-short-links...
# 48  https://www.oreilly.com/radar/four-short-links...
# 49  https://www.oreilly.com/radar/four-short-links...
# 50  https://www.oreilly.com/radar/the-state-of-dat...
# 51  https://www.oreilly.com/radar/four-short-links...
# 52  https://www.oreilly.com/radar/four-short-links...
# 53  https://www.oreilly.com/radar/four-short-links...
# 54  https://www.oreilly.com/radar/four-short-links...
# 55  https://www.oreilly.com/radar/radar-trends-to-...
# 56  https://www.oreilly.com/radar/four-short-links...
# 57  https://www.oreilly.com/radar/four-short-links...
# 58  https://www.oreilly.com/radar/four-short-links...
# 59  https://www.oreilly.com/radar/four-short-links...

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
df['author'].value_counts()
# Out:
# Nat Torkington                     37
# Jenn Webb                           4
# Roger Magoulas and Steve Swoyer     4
# Mike Loukides                       3
# Rita J. King                        1
# Tim O’Reilly                        1
# Mark Richards                       1
# Martin Fowler                       1
# Mac Slocum                          1
# Rachel Laycock and Neal Ford        1
# Pamela Rucker                       1
# Mary Poppendieck                    1
# Kai Holnes                          1
# George Fairbanks                    1
# Cynthia Owens                       1
# Hugo Bowne-Anderson                 1
# Name: author, dtype: int64

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
df['title_length'] = df['title'].apply(len)
df[['title', 'author', 'title_length']].sort_values('title_length', ascending=False)
# Out:
#                                                 title  \
# 32  Highlights from the O’Reilly Software Architec...
# 5   Great leaders inspire innovation and creativit...
# 43  10 ways to get untapped talent in your organiz...
# 6   Strong leaders forge an intersection of knowle...
# 11  It’s an unprecedented crisis: 8 things to do r...
# 3   An enterprise vision is your company’s North Star
# 4    Leaders need to mobilize change-ready workforces
# 0     The unreasonable importance of data preparation
# 45      5 key areas for tech leaders to watch in 2020
# 2       3 ways to confront modern business challenges
# 34         Architecture.Next: Invalidating old axioms
# 33            Where do great architectures come from?
# 9             6 trends framing the state of AI and ML
# 55               Radar trends to watch: February 2020
# 53                 Four short links: 10 February 2020
# 42                 Four short links: 20 February 2020
# 35                 Four short links: 26 February 2020
# 39                 Four short links: 25 February 2020
# 40                 Four short links: 24 February 2020
# 41                 Four short links: 22 February 2020
# 44                 Four short links: 19 February 2020
# 46                 Four short links: 18 February 2020
# 47                 Four short links: 17 February 2020
# 29                 Four short links: 28 February 2020
# 49                 Four short links: 13 February 2020
# 51                 Four short links: 12 February 2020
# 52                 Four short links: 11 February 2020
# 48                 Four short links: 14 February 2020
# 30                 Four short links: 27 February 2020
# 12                 AI adoption in the enterprise 2020
# 59                  Four short links: 3 February 2020
# 58                  Four short links: 4 February 2020
# 57                  Four short links: 5 February 2020
# 56                  Four short links: 6 February 2020
# 54                  Four short links: 7 February 2020
# 36                  From the trenches: Rachel Laycock
# 50                  The state of data quality in 2020
# 22                  Radar trends to watch: March 2020
# 38                   The elephant in the architecture
# 14                    Four short links: 17 March 2020
# 13                    Four short links: 18 March 2020
# 8                     Four short links: 20 March 2020
# 10                    Four short links: 19 March 2020
# 16                    Four short links: 13 March 2020
# 7                     Four short links: 23 March 2020
# 15                    Four short links: 16 March 2020
# 18                    Four short links: 11 March 2020
# 17                    Four short links: 12 March 2020
# 1                     Four short links: 24 March 2020
# 19                    Four short links: 10 March 2020
# 20                     Four short links: 9 March 2020
# 21                     Four short links: 6 March 2020
# 23                     Four short links: 5 March 2020
# 25                     Four short links: 4 March 2020
# 26                     Four short links: 3 March 2020
# 28                     Four short links: 2 March 2020
# 24                          Remembering Freeman Dyson
# 31                               Intellectual control
# 27                                The death of Agile?
# 37                                   Sometimes I draw
#
#                              author  title_length
# 32                       Mac Slocum            78
# 5                         Jenn Webb            76
# 43                    Pamela Rucker            65
# 6                         Jenn Webb            64
# 11                    Cynthia Owens            54
# 3                         Jenn Webb            49
# 4                         Jenn Webb            48
# 0               Hugo Bowne-Anderson            47
# 45  Roger Magoulas and Steve Swoyer            45
# 2                      Rita J. King            45
# 34                    Mark Richards            42
# 33                 Mary Poppendieck            39
# 9   Roger Magoulas and Steve Swoyer            39
# 55                    Mike Loukides            36
# 53                   Nat Torkington            34
# 42                   Nat Torkington            34
# 35                   Nat Torkington            34
# 39                   Nat Torkington            34
# 40                   Nat Torkington            34
# 41                   Nat Torkington            34
# 44                   Nat Torkington            34
# 46                   Nat Torkington            34
# 47                   Nat Torkington            34
# 29                   Nat Torkington            34
# 49                   Nat Torkington            34
# 51                   Nat Torkington            34
# 52                   Nat Torkington            34
# 48                   Nat Torkington            34
# 30                   Nat Torkington            34
# 12  Roger Magoulas and Steve Swoyer            34
# 59                   Nat Torkington            33
# 58                   Nat Torkington            33
# 57                   Nat Torkington            33
# 56                   Nat Torkington            33
# 54                   Nat Torkington            33
# 36     Rachel Laycock and Neal Ford            33
# 50  Roger Magoulas and Steve Swoyer            33
# 22                    Mike Loukides            33
# 38                    Martin Fowler            32
# 14                   Nat Torkington            31
# 13                   Nat Torkington            31
# 8                    Nat Torkington            31
# 10                   Nat Torkington            31
# 16                   Nat Torkington            31
# 7                    Nat Torkington            31
# 15                   Nat Torkington            31
# 18                   Nat Torkington            31
# 17                   Nat Torkington            31
# 1                    Nat Torkington            31
# 19                   Nat Torkington            31
# 20                   Nat Torkington            30
# 21                   Nat Torkington            30
# 23                   Nat Torkington            30
# 25                   Nat Torkington            30
# 26                   Nat Torkington            30
# 28                   Nat Torkington            30
# 24                     Tim O’Reilly            25
# 31                 George Fairbanks            20
# 27                    Mike Loukides            19
# 37                       Kai Holnes            16

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
ML = []
# print(df['summary'])
# summaries = [rss.summary[i].title for i in range(len(rss.entries))]
for ind in df.index:
    if 'machine learning' in df['summary'][ind]:
        ML.append(df['title'][ind])
print(ML)
# Out:
# ['Four short links: 13 February 2020']
